# %%
cd/home/jovyan/scratch/eds/compat/files/optb/ndvi/p093r083
# Out:
# /home/jovyan/scratch/eds/compat/files/optb/ndvi/p093r083

# %%
ls
# Out:
# diagnostics/
# eds_master_results_093_083_ndvi_d20230319_20231013.json
# lztmna_p093r083_eall_dw1mz.hdr
# lztmna_p093r083_eall_dw1mz.img
# lztmna_p093r083_eall_dw1mz.img.aux.xml
# lztmre_p093r083_20160212_dc4ndvi.hdr
# lztmre_p093r083_20160212_dc4ndvi.img
# lztmre_p093r083_20160212_dc4ndvi.img.aux.xml
# lztmre_p093r083_20160228_dc4ndvi.hdr
# lztmre_p093r083_20160228_dc4ndvi.img
# lztmre_p093r083_20160228_dc4ndvi.img.aux.xml
# lztmre_p093r083_20160331_dc4ndvi.hdr
# lztmre_p093r083_20160331_dc4ndvi.img
# lztmre_p093r083_20160331_dc4ndvi.img.aux.xml
# lztmre_p093r083_20160502_dc4ndvi.hdr
# lztmre_p093r083_20160502_dc4ndvi.img
# lztmre_p093r083_20160502_dc4ndvi.img.aux.xml
# lztmre_p093r083_20160923_dc4ndvi.hdr
# lztmre_p093r083_20160923_dc4ndvi.img
# lztmre_p093r083_20160923_dc4ndvi.img.aux.xml
# lztmre_p093r083_20161025_dc4ndvi.hdr
# lztmre_p093r083_20161025_dc4ndvi.img
# lztmre_p093r083_20161025_dc4ndvi.img.aux.xml
# lztmre_p093r083_20161110_dc4ndvi.hdr
# ...
