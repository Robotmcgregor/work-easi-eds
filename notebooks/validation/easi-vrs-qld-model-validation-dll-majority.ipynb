# %% [markdown]
# # EDS vs Queensland validated clearing comparison — DLL Majority Rule
#
# This notebook compares Queensland validated clearing polygons against your DLL classified raster outputs.

# %%
import re
import os
import tempfile
from pathlib import Path

import boto3
import pandas as pd
import geopandas as gpd
import rasterio
from rasterio.mask import mask
import numpy as np
from shapely.geometry import mapping

pd.set_option("display.max_colwidth", 200)
pd.set_option("display.max_rows", 200)

# %%
# -------------------------------------------------------------------
# Configuration
# -------------------------------------------------------------------

MY_BUCKET = "dcceew-eds-data"
MY_PREFIX = "AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/"

QLD_BUCKET = "dcceew-rs-data"
QLD_PREFIX = "dcceew_202602_run/"
QLD_TEXT_FILTER = "completed_checked"

# Evaluate the DLL classified raster
MY_PRODUCT = "dll"

# Australian Albers for combined Australia-wide outputs
COMMON_CRS = "EPSG:3577"

# DLL classes
DLL_NO_CHANGE_CLASS = 10
DLL_CLEARING_CLASSES = {34, 35, 36, 37, 38, 39}
DLL_CLASSES_OF_INTEREST = [10, 34, 35, 36, 37, 38, 39]

# Prediction rule:
# "majority" = polygon predicted cleared when the majority raster class is one of DLL_CLEARING_CLASSES
# "proportion" = polygon predicted cleared when enough pixels fall in DLL_CLEARING_CLASSES
PREDICTION_METHOD = "majority"

# Only used if PREDICTION_METHOD = "proportion"
# Example: 0.5 means at least 50% of pixels in the polygon must be in 34-39.
MIN_PROP_TARGET_CLASS = 0.5

# %%
def list_s3_keys(bucket, prefix=""):
    s3 = boto3.client("s3")
    paginator = s3.get_paginator("list_objects_v2")
    rows = []

    for page in paginator.paginate(Bucket=bucket, Prefix=prefix):
        for obj in page.get("Contents", []):
            rows.append({
                "bucket": bucket,
                "key": obj["Key"],
                "size": obj["Size"],
            })

    return pd.DataFrame(rows)


def find_keys_containing(bucket, prefix="", text="completed_checked", max_show=50):
    s3 = boto3.client("s3")
    paginator = s3.get_paginator("list_objects_v2")

    matches = []

    for page in paginator.paginate(Bucket=bucket, Prefix=prefix):
        for obj in page.get("Contents", []):
            key = obj["Key"]
            if text.lower() in key.lower():
                matches.append(key)

    print(f"Found {len(matches)} keys containing '{text}' under '{prefix}'\n")

    for k in matches[:max_show]:
        print(k)

    if len(matches) > max_show:
        print(f"\n... and {len(matches) - max_show} more")

    return matches


def extract_tile(key):
    m = re.search(r"(p\d{3}r\d{3})", key)
    return m.group(1) if m else None


def extract_date_group(key):
    m = re.search(r"(d\d{16})", key)
    if m:
        return m.group(1)

    m = re.search(r"(?<!\d)(\d{8})(?!\d)", key)
    if m:
        return m.group(1)

    return None


def extract_start_date(date_group):
    if pd.isna(date_group):
        return None

    value = str(date_group)

    m = re.fullmatch(r"d(\d{8})(\d{8})", value)
    if m:
        return m.group(1)

    m = re.fullmatch(r"(\d{8})", value)
    if m:
        return m.group(1)

    m = re.search(r"(?<!\d)(\d{8})(?!\d)", value)
    if m:
        return m.group(1)

    return None


def classify_my_output(key):
    kl = key.lower()
    if not kl.endswith(".tif"):
        return "other"
    if "vi-ndvi_dljmz" in kl:
        return "vi_ndvi_dljmz"
    if "vi-ndvi_dllmz" in kl:
        return "vi_ndvi_dllmz"
    if "_dlj_" in kl:
        return "dlj"
    if "_dll_" in kl:
        return "dll"
    return "raster_other"


def summarise_df(df, name, tile_col="tile", date_col="date_group"):
    print(f"\n===== {name} =====")
    print("Rows:", len(df))

    if "product" in df.columns:
        print("\nProducts:")
        print(df["product"].value_counts(dropna=False))

    if tile_col in df.columns:
        print("\nTiles:")
        print(df[tile_col].value_counts(dropna=False).head(20))

    if date_col in df.columns:
        print("\nDate groups:")
        print(df[date_col].value_counts(dropna=False).head(20))

# %% [markdown]
# ## 1. Build the Queensland validated shapefile inventory
#
# This uses the known `completed_checked` filter under `dcceew_202602_run/`.

# %%
completed_checked_keys = find_keys_containing(
    bucket=QLD_BUCKET,
    prefix=QLD_PREFIX,
    text=QLD_TEXT_FILTER
)

completed_checked_shps = [
    k for k in completed_checked_keys
    if k.lower().endswith(".shp")
]

qld_df = pd.DataFrame({"key_qld": completed_checked_shps})
qld_df["tile"] = qld_df["key_qld"].apply(extract_tile)
qld_df["date_group_qld"] = qld_df["key_qld"].apply(extract_date_group)
qld_df["start_date"] = qld_df["date_group_qld"].apply(extract_start_date)

summarise_df(qld_df, "Queensland validated shapefiles", tile_col="tile", date_col="date_group_qld")
qld_df.head(20)
# Out:
# Found 224 keys containing 'completed_checked' under 'dcceew_202602_run/'
#
# dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.cpg
# dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.dbf
# dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.prj
# dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.sbn
# dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.sbx
# dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shx
# dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.cpg
# dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.dbf
# dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.prj
# dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.sbn
# dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.sbx
# dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.shp
# dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.shx
# dcceew_202602_run/lzolre_p090r077_d2025081720260201_dlwm6_completed/lzolre_p090r077_d2025081720260201_dlwm6_completed_checked.dbf
# dcceew_202602_run/lzolre_p090r077_d2025081720260201_dlwm6_completed/lzolre_p090r077_d2025081720260201_dlwm6_completed_checked.prj
# dcceew_202602_run/lzolre_p090r077_d2025081720260201_dlwm6_completed/lzolre_p090r077_d2025081720260201_dlwm6_completed_checked.shp
# dcceew_202602_run/lzolre_p090r077_d2025081720260201_dlwm6_completed/lzolre_p090r077_d2025081720260201_dlwm6_completed_checked.shx
# dcceew_202602_run/lzolre_p090r079_d2025100420260201_dlwm6/lzolre_p090r079_d2025100420260201_dlwm6_completed_checked.cpg
# dcceew_202602_run/lzolre_p090r079_d2025100420260201_dlwm6/lzolre_p090r079_d2025100420260201_dlwm6_completed_checked.dbf
# dcceew_202602_run/lzolre_p090r079_d2025100420260201_dlwm6/lzolre_p090r079_d2025100420260201_dlwm6_completed_checked.prj
# dcceew_202602_run/lzolre_p090r079_d2025100420260201_dlwm6/lzolre_p090r079_d2025100420260201_dlwm6_completed_checked.sbn
# dcceew_202602_run/lzolre_p090r079_d2025100420260201_dlwm6/lzolre_p090r079_d2025100420260201_dlwm6_completed_checked.sbx
# dcceew_202602_run/lzolre_p090r079_d2025100420260201_dlwm6/lzolre_p090r079_d2025100420260201_dlwm6_completed_checked.shp
# dcceew_202602_run/lzolre_p090r079_d2025100420260201_dlwm6/lzolre_p090r079_d2025100420260201_dlwm6_completed_checked.shx
# dcceew_202602_run/lzolre_p090r086_d2025110520260201_dlwm5/lzolre_p090r086_d2025110520260201_dlwm5_completed_checked.cpg
# dcceew_202602_run/lzolre_p090r086_d2025110520260201_dlwm5/lzolre_p090r086_d2025110520260201_dlwm5_completed_checked.dbf
# dcceew_202602_run/lzolre_p090r086_d2025110520260201_dlwm5/lzolre_p090r086_d2025110520260201_dlwm5_completed_checked.prj
# dcceew_202602_run/lzolre_p090r086_d2025110520260201_dlwm5/lzolre_p090r086_d2025110520260201_dlwm5_completed_checked.sbn
# dcceew_202602_run/lzolre_p090r086_d2025110520260201_dlwm5/lzolre_p090r086_d2025110520260201_dlwm5_completed_checked.sbx
# dcceew_202602_run/lzolre_p090r086_d2025110520260201_dlwm5/lzolre_p090r086_d2025110520260201_dlwm5_completed_checked.shp
# dcceew_202602_run/lzolre_p090r086_d2025110520260201_dlwm5/lzolre_p090r086_d2025110520260201_dlwm5_completed_checked.shx
# dcceew_202602_run/lzolre_p090r088_d2025101220260201_dlwm5/lzolre_p090r088_d2025101220260201_dlwm5_completed_checked.cpg
# dcceew_202602_run/lzolre_p090r088_d2025101220260201_dlwm5/lzolre_p090r088_d2025101220260201_dlwm5_completed_checked.dbf
# dcceew_202602_run/lzolre_p090r088_d2025101220260201_dlwm5/lzolre_p090r088_d2025101220260201_dlwm5_completed_checked.prj
# dcceew_202602_run/lzolre_p090r088_d2025101220260201_dlwm5/lzolre_p090r088_d2025101220260201_dlwm5_completed_checked.sbn
# dcceew_202602_run/lzolre_p090r088_d2025101220260201_dlwm5/lzolre_p090r088_d2025101220260201_dlwm5_completed_checked.sbx
# dcceew_202602_run/lzolre_p090r088_d2025101220260201_dlwm5/lzolre_p090r088_d2025101220260201_dlwm5_completed_checked.shp
# dcceew_202602_run/lzolre_p090r088_d2025101220260201_dlwm5/lzolre_p090r088_d2025101220260201_dlwm5_completed_checked.shx
# dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.cpg
# dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.dbf
# dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.prj
# dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.sbn
# dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.sbx
# dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.shp
# dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.shx
# dcceew_202602_run/lzolre_p091r076_d2025081620260131_dlwm6/lzolre_p091r076_d2025081620260131_dlwm6_completed_checked.cpg
# dcceew_202602_run/lzolre_p091r076_d2025081620260131_dlwm6/lzolre_p091r076_d2025081620260131_dlwm6_completed_checked.dbf
# dcceew_202602_run/lzolre_p091r076_d2025081620260131_dlwm6/lzolre_p091r076_d2025081620260131_dlwm6_completed_checked.prj
# dcceew_202602_run/lzolre_p091r076_d2025081620260131_dlwm6/lzolre_p091r076_d2025081620260131_dlwm6_completed_checked.sbn
#
# ... and 174 more
#
# ===== Queensland validated shapefiles =====
# Rows: 33
#
# Tiles:
# tile
# p089r078    1
# p089r084    1
# p090r077    1
# p090r079    1
# p090r086    1
# p090r088    1
# p090r090    1
# p091r076    1
# p091r077    1
# p092r076    1
# p092r077    1
# p092r087    1
# p092r088    1
# p093r075    1
# p093r076    1
# p093r077    1
# p094r077    1
# p094r087    1
# p095r073    1
# p096r086    1
# Name: count, dtype: int64
#
# Date groups:
# date_group_qld
# d2025082020260111    2
# d2025070120260117    1
# d2025081720260201    1
# d2025091120260109    1
# d2025110520260201    1
# d2025101220260201    1
# d2025061420251121    1
# d2025100420260201    1
# d2025091720260131    1
# d2025100220260122    1
# d2025112820260123    1
# d2025062120260123    1
# d2025073120260123    1
# d2025101820260122    1
# d2025100220260130    1
# d2025081620260131    1
# d2025092420260130    1
# d2025111820260206    1
# d2025093020251211    1
# d2025081420260105    1
# Name: count, dtype: int64
#                                                                                                                               key_qld  \
# 0             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 1             dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.shp
# 2   dcceew_202602_run/lzolre_p090r077_d2025081720260201_dlwm6_completed/lzolre_p090r077_d2025081720260201_dlwm6_completed_checked.shp
# 3             dcceew_202602_run/lzolre_p090r079_d2025100420260201_dlwm6/lzolre_p090r079_d2025100420260201_dlwm6_completed_checked.shp
# 4             dcceew_202602_run/lzolre_p090r086_d2025110520260201_dlwm5/lzolre_p090r086_d2025110520260201_dlwm5_completed_checked.shp
# 5             dcceew_202602_run/lzolre_p090r088_d2025101220260201_dlwm5/lzolre_p090r088_d2025101220260201_dlwm5_completed_checked.shp
# 6             dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.shp
# 7             dcceew_202602_run/lzolre_p091r076_d2025081620260131_dlwm6/lzolre_p091r076_d2025081620260131_dlwm6_completed_checked.shp
# 8             dcceew_202602_run/lzolre_p091r077_d2025091720260131_dlwm6/lzolre_p091r077_d2025091720260131_dlwm6_completed_checked.shp
# 9             dcceew_202602_run/lzolre_p092r076_d2025100220260122_dlwm5/lzolre_p092r076_d2025100220260122_dlwm5_completed_checked.shp
# 10            dcceew_202602_run/lzolre_p092r077_d2025112820260123_dlwm5/lzolre_p092r077_d2025112820260123_dlwm5_completed_checked.shp
# 11            dcceew_202602_run/lzolre_p092r087_d2025062120260123_dlwm5/lzolre_p092r087_d2025062120260123_dlwm5_completed_checked.shp
# 12            dcceew_202602_run/lzolre_p092r088_d2025073120260123_dlwm5/lzolre_p092r088_d2025073120260123_dlwm5_completed_checked.shp
# 13            dcceew_202602_run/lzolre_p093r075_d2025101820260122_dlwm5/lzolre_p093r075_d2025101820260122_dlwm5_completed_checked.shp
# 14            dcceew_202602_run/lzolre_p093r076_d2025100220260130_dlwm5/lzolre_p093r076_d2025100220260130_dlwm5_completed_checked.shp
# 15  dcceew_202602_run/lzolre_p093r077_d2025092420260130_dlwm5_completed/lzolre_p093r077_d2025092420260130_dlwm5_completed_checked.shp
# 16            dcceew_202602_run/lzolre_p094r077_d2025111820260206_dlwm5/lzolre_p094r077_d2025111820260206_dlwm5_completed_checked.shp
# 17            dcceew_202602_run/lzolre_p094r087_d2025081420260105_dlwm4/lzolre_p094r087_d2025081420260105_dlwm4_completed_checked.shp
# 18            dcceew_202602_run/lzolre_p095r073_d2025093020251211_dlwm5/lzolre_p095r073_d2025093020251211_dlwm5_completed_checked.shp
# 19            dcceew_202602_run/lzolre_p096r086_d2025101520251218_dlwm4/lzolre_p096r086_d2025101520251218_dlwm4_completed_checked.shp
#
#         tile     date_group_qld start_date
# 0   p089r078  d2025070120260117   20250701
# 1   p089r084  d2025091120260109   20250911
# 2   p090r077  d2025081720260201   20250817
# 3   p090r079  d2025100420260201   20251004
# 4   p090r086  d2025110520260201   20251105
# 5   p090r088  d2025101220260201   20251012
# 6   p090r090  d2025061420251121   20250614
# 7   p091r076  d2025081620260131   20250816
# 8   p091r077  d2025091720260131   20250917
# 9   p092r076  d2025100220260122   20251002
# 10  p092r077  d2025112820260123   20251128
# 11  p092r087  d2025062120260123   20250621
# 12  p092r088  d2025073120260123   20250731
# 13  p093r075  d2025101820260122   20251018
# 14  p093r076  d2025100220260130   20251002
# 15  p093r077  d2025092420260130   20250924
# 16  p094r077  d2025111820260206   20251118
# 17  p094r087  d2025081420260105   20250814
# 18  p095r073  d2025093020251211   20250930
# 19  p096r086  d2025101520251218   20251015

# %% [markdown]
# ## 2. Build your EDS output inventory
#
# This looks only under your `tiles/` prefix and keeps the `.tif` rasters under `/outputs/`.

# %%
df_my = list_s3_keys(MY_BUCKET, MY_PREFIX)

my_outputs = df_my[
    df_my["key"].str.contains("/outputs/", case=False, na=False)
].copy()

my_outputs = my_outputs[
    my_outputs["key"].str.lower().str.endswith(".tif")
].copy()

my_outputs["tile"] = my_outputs["key"].apply(extract_tile)
my_outputs["date_group_my"] = my_outputs["key"].apply(extract_date_group)
my_outputs["start_date"] = my_outputs["date_group_my"].apply(extract_start_date)
my_outputs["product"] = my_outputs["key"].apply(classify_my_output)

summarise_df(my_outputs, "My EDS outputs", tile_col="tile", date_col="date_group_my")
my_outputs.head(20)
# Out:
# ===== My EDS outputs =====
# Rows: 352
#
# Products:
# product
# raster_other    176
# dlj              88
# dll              88
# Name: count, dtype: int64
#
# Tiles:
# tile
# p089r078    32
# p089r079    20
# p089r081    16
# p089r084    16
# p107r084    16
# p112r076    16
# p115r076    16
# p115r077    16
# p115r078    16
# p115r079    16
# p090r090    12
# p107r081    12
# p090r085     8
# p090r082     8
# p089r082     8
# p089r080     8
# p090r079     8
# p090r077     8
# p107r071     8
# p090r086     4
# Name: count, dtype: int64
#
# Date groups:
# date_group_my
# d2025112920260201    48
# d2025070120260117    32
# d2025060720260125    28
# d2025082620260125    24
# d2025091120260109    16
# d2025092920260204    16
# d2025112920260124    16
# d2025080120260209    16
# d2025061420251121    12
# d2025092620260217    12
# d2025081720260201     8
# d2025091820260201     8
# d2025100420260201     8
# d2025082020260111     8
# d2025063020251129     8
# d2025110520260124     8
# d2025100220260122     4
# d2025110520260201     4
# d2025081620260131     4
# d2025091720260131     4
# Name: count, dtype: int64
#               bucket  \
# 392  dcceew-eds-data
# 393  dcceew-eds-data
# 394  dcceew-eds-data
# 395  dcceew-eds-data
# 406  dcceew-eds-data
# 407  dcceew-eds-data
# 408  dcceew-eds-data
# 409  dcceew-eds-data
# 430  dcceew-eds-data
# 431  dcceew-eds-data
# 432  dcceew-eds-data
# 433  dcceew-eds-data
# 444  dcceew-eds-data
# 445  dcceew-eds-data
# 446  dcceew-eds-data
# 447  dcceew-eds-data
# 458  dcceew-eds-data
# 459  dcceew-eds-data
# 460  dcceew-eds-data
# 461  dcceew-eds-data
#
#                                                                                                                                                                    key  \
# 392                                                 AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/02/l9olre_p089r078_d2025070120260117_dlj_e32756.tif
# 393                                                 AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/02/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 394                            AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/02/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-clear-ge80_e32756.tif
# 395                           AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/02/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-strong-ge60_e32756.tif
# 406                         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/p089r078_d2025070120260117/l9olre_p089r078_d2025070120260117_dlj_e32756.tif
# 407                         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/p089r078_d2025070120260117/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 408    AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/p089r078_d2025070120260117/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-clear-ge80_e32756.tif
# 409   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/p089r078_d2025070120260117/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-strong-ge60_e32756.tif
# 430                                     AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-auto-scale/l9olre_p089r078_d2025070120260117_dlj_e32756.tif
# 431                                     AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-auto-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 432                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-auto-scale/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-clear-ge80_e32756.tif
# 433               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-auto-scale/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-strong-ge60_e32756.tif
# 444                        AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-baseline-include-nodata/l9olre_p089r078_d2025070120260117_dlj_e32756.tif
# 445                        AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-baseline-include-nodata/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 446   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-baseline-include-nodata/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-clear-ge80_e32756.tif
# 447  AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-baseline-include-nodata/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-strong-ge60_e32756.tif
# 458                                   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-forced-10000/l9olre_p089r078_d2025070120260117_dlj_e32756.tif
# 459                                   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-forced-10000/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 460              AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-forced-10000/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-clear-ge80_e32756.tif
# 461             AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-forced-10000/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-strong-ge60_e32756.tif
#
#          size      tile      date_group_my start_date       product
# 392  21677478  p089r078  d2025070120260117   20250701           dlj
# 393   1887589  p089r078  d2025070120260117   20250701           dll
# 394   1599789  p089r078  d2025070120260117   20250701  raster_other
# 395   1619403  p089r078  d2025070120260117   20250701  raster_other
# 406  19662686  p089r078  d2025070120260117   20250701           dlj
# 407    656753  p089r078  d2025070120260117   20250701           dll
# 408    264825  p089r078  d2025070120260117   20250701  raster_other
# 409    275969  p089r078  d2025070120260117   20250701  raster_other
# 430  19934984  p089r078  d2025070120260117   20250701           dlj
# 431    768741  p089r078  d2025070120260117   20250701           dll
# 432    342303  p089r078  d2025070120260117   20250701  raster_other
# 433    358133  p089r078  d2025070120260117   20250701  raster_other
# 444  19521730  p089r078  d2025070120260117   20250701           dlj
# 445    650815  p089r078  d2025070120260117   20250701           dll
# 446    269669  p089r078  d2025070120260117   20250701  raster_other
# 447    280069  p089r078  d2025070120260117   20250701  raster_other
# 458  19934984  p089r078  d2025070120260117   20250701           dlj
# 459    768741  p089r078  d2025070120260117   20250701           dll
# 460    342303  p089r078  d2025070120260117   20250701  raster_other
# 461    358133  p089r078  d2025070120260117   20250701  raster_other

# %% [markdown]
# ### 2.b look at data

# %%
import pandas as pd
pd.set_option("display.max_colwidth", 200)

qld_view = qld_df[[
    "tile",
    "date_group_qld",
    "start_date",
    "key_qld"
]].copy()

print("Queensland shapefiles:")
display(qld_view.sort_values(["tile", "start_date"]).head(50))
# Out:
# Queensland shapefiles:
#         tile     date_group_qld start_date  \
# 0   p089r078  d2025070120260117   20250701
# 1   p089r084  d2025091120260109   20250911
# 2   p090r077  d2025081720260201   20250817
# 3   p090r079  d2025100420260201   20251004
# 4   p090r086  d2025110520260201   20251105
# 5   p090r088  d2025101220260201   20251012
# 6   p090r090  d2025061420251121   20250614
# 7   p091r076  d2025081620260131   20250816
# 8   p091r077  d2025091720260131   20250917
# 9   p092r076  d2025100220260122   20251002
# 10  p092r077  d2025112820260123   20251128
# 11  p092r087  d2025062120260123   20250621
# 12  p092r088  d2025073120260123   20250731
# 13  p093r075  d2025101820260122   20251018
# 14  p093r076  d2025100220260130   20251002
# 15  p093r077  d2025092420260130   20250924
# 16  p094r077  d2025111820260206   20251118
# 17  p094r087  d2025081420260105   20250814
# 18  p095r073  d2025093020251211   20250930
# 19  p096r086  d2025101520251218   20251015
# 20  p097r074  d2025090420260110   20250904
# 21  p099r069  d2025082520251215   20250825
# 22  p102r074  d2025092320260121   20250923
# 23  p104r070  d2025082020260111   20250820
# 24  p104r071  d2025082020260111   20250820
# 25  p105r070  d2025090420251209   20250904
# 26  p106r069  d2025081820251013   20250818
# 27  p108r070  d2025071520260107   20250715
# 28  p108r084  d2025111220260208   20251112
# 29  p109r081  d2025101020260215   20251010
# 30  p110r082  d2025101720260206   20251017
# 31  p112r076  d2025092920260204   20250929
# 32  p114r080  d2025101320260218   20251013
#
#                                                                                                                               key_qld
# 0             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 1             dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.shp
# 2   dcceew_202602_run/lzolre_p090r077_d2025081720260201_dlwm6_completed/lzolre_p090r077_d2025081720260201_dlwm6_completed_checked.shp
# 3             dcceew_202602_run/lzolre_p090r079_d2025100420260201_dlwm6/lzolre_p090r079_d2025100420260201_dlwm6_completed_checked.shp
# 4             dcceew_202602_run/lzolre_p090r086_d2025110520260201_dlwm5/lzolre_p090r086_d2025110520260201_dlwm5_completed_checked.shp
# 5             dcceew_202602_run/lzolre_p090r088_d2025101220260201_dlwm5/lzolre_p090r088_d2025101220260201_dlwm5_completed_checked.shp
# 6             dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.shp
# 7             dcceew_202602_run/lzolre_p091r076_d2025081620260131_dlwm6/lzolre_p091r076_d2025081620260131_dlwm6_completed_checked.shp
# 8             dcceew_202602_run/lzolre_p091r077_d2025091720260131_dlwm6/lzolre_p091r077_d2025091720260131_dlwm6_completed_checked.shp
# 9             dcceew_202602_run/lzolre_p092r076_d2025100220260122_dlwm5/lzolre_p092r076_d2025100220260122_dlwm5_completed_checked.shp
# 10            dcceew_202602_run/lzolre_p092r077_d2025112820260123_dlwm5/lzolre_p092r077_d2025112820260123_dlwm5_completed_checked.shp
# 11            dcceew_202602_run/lzolre_p092r087_d2025062120260123_dlwm5/lzolre_p092r087_d2025062120260123_dlwm5_completed_checked.shp
# 12            dcceew_202602_run/lzolre_p092r088_d2025073120260123_dlwm5/lzolre_p092r088_d2025073120260123_dlwm5_completed_checked.shp
# 13            dcceew_202602_run/lzolre_p093r075_d2025101820260122_dlwm5/lzolre_p093r075_d2025101820260122_dlwm5_completed_checked.shp
# 14            dcceew_202602_run/lzolre_p093r076_d2025100220260130_dlwm5/lzolre_p093r076_d2025100220260130_dlwm5_completed_checked.shp
# 15  dcceew_202602_run/lzolre_p093r077_d2025092420260130_dlwm5_completed/lzolre_p093r077_d2025092420260130_dlwm5_completed_checked.shp
# 16            dcceew_202602_run/lzolre_p094r077_d2025111820260206_dlwm5/lzolre_p094r077_d2025111820260206_dlwm5_completed_checked.shp
# 17            dcceew_202602_run/lzolre_p094r087_d2025081420260105_dlwm4/lzolre_p094r087_d2025081420260105_dlwm4_completed_checked.shp
# 18            dcceew_202602_run/lzolre_p095r073_d2025093020251211_dlwm5/lzolre_p095r073_d2025093020251211_dlwm5_completed_checked.shp
# 19            dcceew_202602_run/lzolre_p096r086_d2025101520251218_dlwm4/lzolre_p096r086_d2025101520251218_dlwm4_completed_checked.shp
# 20            dcceew_202602_run/lzolre_p097r074_d2025090420260110_dlwm4/lzolre_p097r074_d2025090420260110_dlwm4_completed_checked.shp
# 21            dcceew_202602_run/lzolre_p099r069_d2025082520251215_dlwm4/lzolre_p099r069_d2025082520251215_dlwm4_completed_checked.shp
# 22            dcceew_202602_run/lzolre_p102r074_d2025092320260121_dlwm3/lzolre_p102r074_d2025092320260121_dlwm3_completed_checked.shp
# 23            dcceew_202602_run/lzolre_p104r070_d2025082020260111_dlwm3/lzolre_p104r070_d2025082020260111_dlwm3_completed_checked.shp
# 24            dcceew_202602_run/lzolre_p104r071_d2025082020260111_dlwm3/lzolre_p104r071_d2025082020260111_dlwm3_completed_checked.shp
# 25            dcceew_202602_run/lzolre_p105r070_d2025090420251209_dlwm2/lzolre_p105r070_d2025090420251209_dlwm2_completed_checked.shp
# 26            dcceew_202602_run/lzolre_p106r069_d2025081820251013_dlwm2/lzolre_p106r069_d2025081820251013_dlwm2_completed_checked.shp
# 27            dcceew_202602_run/lzolre_p108r070_d2025071520260107_dlwm2/lzolre_p108r070_d2025071520260107_dlwm2_completed_checked.shp
# 28            dcceew_202602_run/lzolre_p108r084_d2025111220260208_dlwm1/lzolre_p108r084_d2025111220260208_dlwm1_completed_checked.shp
# 29            dcceew_202602_run/lzolre_p109r081_d2025101020260215_dlwm1/lzolre_p109r081_d2025101020260215_dlwm1_completed_checked.shp
# 30            dcceew_202602_run/lzolre_p110r082_d2025101720260206_dlwm0/lzolre_p110r082_d2025101720260206_dlwm0_completed_checked.shp
# 31            dcceew_202602_run/lzolre_p112r076_d2025092920260204_dlwm0/lzolre_p112r076_d2025092920260204_dlwm0_completed_checked.shp
# 32            dcceew_202602_run/lzolre_p114r080_d2025101320260218_dlwm0/lzolre_p114r080_d2025101320260218_dlwm0_completed_checked.shp

# %%
my_view = my_outputs[[
    "tile",
    "product",
    "date_group_my",
    "start_date",
    "key"
]].copy()

print("My EDS rasters:")
display(my_view.sort_values(["tile", "start_date", "product"]).head(100))
# Out:
# My EDS rasters:
#           tile       product      date_group_my start_date  \
# 392   p089r078           dlj  d2025070120260117   20250701
# 406   p089r078           dlj  d2025070120260117   20250701
# 430   p089r078           dlj  d2025070120260117   20250701
# 444   p089r078           dlj  d2025070120260117   20250701
# 458   p089r078           dlj  d2025070120260117   20250701
# 472   p089r078           dlj  d2025070120260117   20250701
# 486   p089r078           dlj  d2025070120260117   20250701
# 500   p089r078           dlj  d2025070120260117   20250701
# 393   p089r078           dll  d2025070120260117   20250701
# 407   p089r078           dll  d2025070120260117   20250701
# 431   p089r078           dll  d2025070120260117   20250701
# 445   p089r078           dll  d2025070120260117   20250701
# 459   p089r078           dll  d2025070120260117   20250701
# 473   p089r078           dll  d2025070120260117   20250701
# 487   p089r078           dll  d2025070120260117   20250701
# 501   p089r078           dll  d2025070120260117   20250701
# 394   p089r078  raster_other  d2025070120260117   20250701
# 395   p089r078  raster_other  d2025070120260117   20250701
# 408   p089r078  raster_other  d2025070120260117   20250701
# 409   p089r078  raster_other  d2025070120260117   20250701
# 432   p089r078  raster_other  d2025070120260117   20250701
# 433   p089r078  raster_other  d2025070120260117   20250701
# 446   p089r078  raster_other  d2025070120260117   20250701
# 447   p089r078  raster_other  d2025070120260117   20250701
# 460   p089r078  raster_other  d2025070120260117   20250701
# 461   p089r078  raster_other  d2025070120260117   20250701
# 474   p089r078  raster_other  d2025070120260117   20250701
# 475   p089r078  raster_other  d2025070120260117   20250701
# 488   p089r078  raster_other  d2025070120260117   20250701
# 489   p089r078  raster_other  d2025070120260117   20250701
# 502   p089r078  raster_other  d2025070120260117   20250701
# 503   p089r078  raster_other  d2025070120260117   20250701
# 938   p089r079           dlj  d2025060720260125   20250607
# 952   p089r079           dlj  d2025060720260125   20250607
# 966   p089r079           dlj  d2025060720260125   20250607
# 980   p089r079           dlj  d2025060720260125   20250607
# 994   p089r079           dlj  d2025060720260125   20250607
# 939   p089r079           dll  d2025060720260125   20250607
# 953   p089r079           dll  d2025060720260125   20250607
# 967   p089r079           dll  d2025060720260125   20250607
# 981   p089r079           dll  d2025060720260125   20250607
# 995   p089r079           dll  d2025060720260125   20250607
# 940   p089r079  raster_other  d2025060720260125   20250607
# 941   p089r079  raster_other  d2025060720260125   20250607
# 954   p089r079  raster_other  d2025060720260125   20250607
# 955   p089r079  raster_other  d2025060720260125   20250607
# 968   p089r079  raster_other  d2025060720260125   20250607
# 969   p089r079  raster_other  d2025060720260125   20250607
# 982   p089r079  raster_other  d2025060720260125   20250607
# 983   p089r079  raster_other  d2025060720260125   20250607
# 996   p089r079  raster_other  d2025060720260125   20250607
# 997   p089r079  raster_other  d2025060720260125   20250607
# 1406  p089r080           dlj  d2025060720260125   20250607
# 1420  p089r080           dlj  d2025060720260125   20250607
# 1407  p089r080           dll  d2025060720260125   20250607
# 1421  p089r080           dll  d2025060720260125   20250607
# 1408  p089r080  raster_other  d2025060720260125   20250607
# 1409  p089r080  raster_other  d2025060720260125   20250607
# 1422  p089r080  raster_other  d2025060720260125   20250607
# 1423  p089r080  raster_other  d2025060720260125   20250607
# 1739  p089r081           dlj  d2025082620260125   20250826
# 1753  p089r081           dlj  d2025082620260125   20250826
# 1767  p089r081           dlj  d2025082620260125   20250826
# 1781  p089r081           dlj  d2025082620260125   20250826
# 1740  p089r081           dll  d2025082620260125   20250826
# 1754  p089r081           dll  d2025082620260125   20250826
# 1768  p089r081           dll  d2025082620260125   20250826
# 1782  p089r081           dll  d2025082620260125   20250826
# 1741  p089r081  raster_other  d2025082620260125   20250826
# 1742  p089r081  raster_other  d2025082620260125   20250826
# 1755  p089r081  raster_other  d2025082620260125   20250826
# 1756  p089r081  raster_other  d2025082620260125   20250826
# 1769  p089r081  raster_other  d2025082620260125   20250826
# 1770  p089r081  raster_other  d2025082620260125   20250826
# 1783  p089r081  raster_other  d2025082620260125   20250826
# 1784  p089r081  raster_other  d2025082620260125   20250826
# 2074  p089r082           dlj  d2025082620260125   20250826
# 2088  p089r082           dlj  d2025082620260125   20250826
# 2075  p089r082           dll  d2025082620260125   20250826
# 2089  p089r082           dll  d2025082620260125   20250826
# 2076  p089r082  raster_other  d2025082620260125   20250826
# 2077  p089r082  raster_other  d2025082620260125   20250826
# 2090  p089r082  raster_other  d2025082620260125   20250826
# 2091  p089r082  raster_other  d2025082620260125   20250826
# 2561  p089r084           dlj  d2025091120260109   20250911
# 2575  p089r084           dlj  d2025091120260109   20250911
# 2589  p089r084           dlj  d2025091120260109   20250911
# 2603  p089r084           dlj  d2025091120260109   20250911
# 2562  p089r084           dll  d2025091120260109   20250911
# 2576  p089r084           dll  d2025091120260109   20250911
# 2590  p089r084           dll  d2025091120260109   20250911
# 2604  p089r084           dll  d2025091120260109   20250911
# 2563  p089r084  raster_other  d2025091120260109   20250911
# 2564  p089r084  raster_other  d2025091120260109   20250911
# 2577  p089r084  raster_other  d2025091120260109   20250911
# 2578  p089r084  raster_other  d2025091120260109   20250911
# 2591  p089r084  raster_other  d2025091120260109   20250911
# 2592  p089r084  raster_other  d2025091120260109   20250911
# 2605  p089r084  raster_other  d2025091120260109   20250911
# 2606  p089r084  raster_other  d2025091120260109   20250911
#
#                                                                                                                                                                     key
# 392                                                  AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/02/l9olre_p089r078_d2025070120260117_dlj_e32756.tif
# 406                          AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/p089r078_d2025070120260117/l9olre_p089r078_d2025070120260117_dlj_e32756.tif
# 430                                      AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-auto-scale/l9olre_p089r078_d2025070120260117_dlj_e32756.tif
# 444                         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-baseline-include-nodata/l9olre_p089r078_d2025070120260117_dlj_e32756.tif
# 458                                    AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-forced-10000/l9olre_p089r078_d2025070120260117_dlj_e32756.tif
# 472                                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-no-auto-sr-scale/l9olre_p089r078_d2025070120260117_dlj_e32756.tif
# 486                                     AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runs-auto-scale/l9olre_p089r078_d2025070120260117_dlj_e32756.tif
# 500                                  AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runsrno-auto-scale/l9olre_p089r078_d2025070120260117_dlj_e32756.tif
# 393                                                  AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/02/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 407                          AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/p089r078_d2025070120260117/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 431                                      AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-auto-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 445                         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-baseline-include-nodata/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 459                                    AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-forced-10000/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 473                                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-no-auto-sr-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 487                                     AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runs-auto-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 501                                  AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runsrno-auto-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 394                             AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/02/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-clear-ge80_e32756.tif
# 395                            AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/02/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-strong-ge60_e32756.tif
# 408     AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/p089r078_d2025070120260117/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-clear-ge80_e32756.tif
# 409    AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/p089r078_d2025070120260117/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-strong-ge60_e32756.tif
# 432                 AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-auto-scale/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-clear-ge80_e32756.tif
# 433                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-auto-scale/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-strong-ge60_e32756.tif
# 446    AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-baseline-include-nodata/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-clear-ge80_e32756.tif
# 447   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-baseline-include-nodata/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-strong-ge60_e32756.tif
# 460               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-forced-10000/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-clear-ge80_e32756.tif
# 461              AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-forced-10000/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-strong-ge60_e32756.tif
# 474           AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-no-auto-sr-scale/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-clear-ge80_e32756.tif
# 475          AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-no-auto-sr-scale/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-strong-ge60_e32756.tif
# 488                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runs-auto-scale/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-clear-ge80_e32756.tif
# 489               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runs-auto-scale/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-strong-ge60_e32756.tif
# 502             AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runsrno-auto-scale/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-clear-ge80_e32756.tif
# 503            AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runsrno-auto-scale/masks/l9olre_p089r078_d2025070120260117_dlj-dlj-strong-ge60_e32756.tif
# 938                                                  AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/02/l8olre_p089r079_d2025060720260125_dlj_e32756.tif
# 952                          AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/p089r079_d2025060720260125/l8olre_p089r079_d2025060720260125_dlj_e32756.tif
# 966                                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/run-no-auto-sr-scale/l8olre_p089r079_d2025060720260125_dlj_e32756.tif
# 980                                     AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/runs-auto-scale/l8olre_p089r079_d2025060720260125_dlj_e32756.tif
# 994                                  AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/runsrno-auto-scale/l8olre_p089r079_d2025060720260125_dlj_e32756.tif
# 939                                                  AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/02/l8olre_p089r079_d2025060720260125_dll_e32756.tif
# 953                          AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/p089r079_d2025060720260125/l8olre_p089r079_d2025060720260125_dll_e32756.tif
# 967                                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/run-no-auto-sr-scale/l8olre_p089r079_d2025060720260125_dll_e32756.tif
# 981                                     AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/runs-auto-scale/l8olre_p089r079_d2025060720260125_dll_e32756.tif
# 995                                  AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/runsrno-auto-scale/l8olre_p089r079_d2025060720260125_dll_e32756.tif
# 940                             AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/02/masks/l8olre_p089r079_d2025060720260125_dlj-dlj-clear-ge80_e32756.tif
# 941                            AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/02/masks/l8olre_p089r079_d2025060720260125_dlj-dlj-strong-ge60_e32756.tif
# 954     AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/p089r079_d2025060720260125/masks/l8olre_p089r079_d2025060720260125_dlj-dlj-clear-ge80_e32756.tif
# 955    AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/p089r079_d2025060720260125/masks/l8olre_p089r079_d2025060720260125_dlj-dlj-strong-ge60_e32756.tif
# 968           AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/run-no-auto-sr-scale/masks/l8olre_p089r079_d2025060720260125_dlj-dlj-clear-ge80_e32756.tif
# 969          AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/run-no-auto-sr-scale/masks/l8olre_p089r079_d2025060720260125_dlj-dlj-strong-ge60_e32756.tif
# 982                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/runs-auto-scale/masks/l8olre_p089r079_d2025060720260125_dlj-dlj-clear-ge80_e32756.tif
# 983               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/runs-auto-scale/masks/l8olre_p089r079_d2025060720260125_dlj-dlj-strong-ge60_e32756.tif
# 996             AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/runsrno-auto-scale/masks/l8olre_p089r079_d2025060720260125_dlj-dlj-clear-ge80_e32756.tif
# 997            AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r079/outputs/runsrno-auto-scale/masks/l8olre_p089r079_d2025060720260125_dlj-dlj-strong-ge60_e32756.tif
# 1406                                                 AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r080/outputs/02/l8olre_p089r080_d2025060720260125_dlj_e32756.tif
# 1420                         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r080/outputs/p089r080_d2025060720260125/l8olre_p089r080_d2025060720260125_dlj_e32756.tif
# 1407                                                 AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r080/outputs/02/l8olre_p089r080_d2025060720260125_dll_e32756.tif
# 1421                         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r080/outputs/p089r080_d2025060720260125/l8olre_p089r080_d2025060720260125_dll_e32756.tif
# 1408                            AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r080/outputs/02/masks/l8olre_p089r080_d2025060720260125_dlj-dlj-clear-ge80_e32756.tif
# 1409                           AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r080/outputs/02/masks/l8olre_p089r080_d2025060720260125_dlj-dlj-strong-ge60_e32756.tif
# 1422    AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r080/outputs/p089r080_d2025060720260125/masks/l8olre_p089r080_d2025060720260125_dlj-dlj-clear-ge80_e32756.tif
# 1423   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r080/outputs/p089r080_d2025060720260125/masks/l8olre_p089r080_d2025060720260125_dlj-dlj-strong-ge60_e32756.tif
# 1739                         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/p089r081_d2025082620260125/l8olre_p089r081_d2025082620260125_dlj_e32756.tif
# 1753                                     AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/run-auto-scale/l8olre_p089r081_d2025082620260125_dlj_e32756.tif
# 1767                                   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/run-forced-10000/l8olre_p089r081_d2025082620260125_dlj_e32756.tif
# 1781                               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/run-no-auto-sr-scale/l8olre_p089r081_d2025082620260125_dlj_e32756.tif
# 1740                         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/p089r081_d2025082620260125/l8olre_p089r081_d2025082620260125_dll_e32756.tif
# 1754                                     AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/run-auto-scale/l8olre_p089r081_d2025082620260125_dll_e32756.tif
# 1768                                   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/run-forced-10000/l8olre_p089r081_d2025082620260125_dll_e32756.tif
# 1782                               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/run-no-auto-sr-scale/l8olre_p089r081_d2025082620260125_dll_e32756.tif
# 1741    AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/p089r081_d2025082620260125/masks/l8olre_p089r081_d2025082620260125_dlj-dlj-clear-ge80_e32756.tif
# 1742   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/p089r081_d2025082620260125/masks/l8olre_p089r081_d2025082620260125_dlj-dlj-strong-ge60_e32756.tif
# 1755                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/run-auto-scale/masks/l8olre_p089r081_d2025082620260125_dlj-dlj-clear-ge80_e32756.tif
# 1756               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/run-auto-scale/masks/l8olre_p089r081_d2025082620260125_dlj-dlj-strong-ge60_e32756.tif
# 1769              AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/run-forced-10000/masks/l8olre_p089r081_d2025082620260125_dlj-dlj-clear-ge80_e32756.tif
# 1770             AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/run-forced-10000/masks/l8olre_p089r081_d2025082620260125_dlj-dlj-strong-ge60_e32756.tif
# 1783          AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/run-no-auto-sr-scale/masks/l8olre_p089r081_d2025082620260125_dlj-dlj-clear-ge80_e32756.tif
# 1784         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r081/outputs/run-no-auto-sr-scale/masks/l8olre_p089r081_d2025082620260125_dlj-dlj-strong-ge60_e32756.tif
# 2074                         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r082/outputs/p089r082_d2025082620260125/l8olre_p089r082_d2025082620260125_dlj_e32756.tif
# 2088                               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r082/outputs/run-no-auto-sr-scale/l8olre_p089r082_d2025082620260125_dlj_e32756.tif
# 2075                         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r082/outputs/p089r082_d2025082620260125/l8olre_p089r082_d2025082620260125_dll_e32756.tif
# 2089                               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r082/outputs/run-no-auto-sr-scale/l8olre_p089r082_d2025082620260125_dll_e32756.tif
# 2076    AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r082/outputs/p089r082_d2025082620260125/masks/l8olre_p089r082_d2025082620260125_dlj-dlj-clear-ge80_e32756.tif
# 2077   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r082/outputs/p089r082_d2025082620260125/masks/l8olre_p089r082_d2025082620260125_dlj-dlj-strong-ge60_e32756.tif
# 2090          AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r082/outputs/run-no-auto-sr-scale/masks/l8olre_p089r082_d2025082620260125_dlj-dlj-clear-ge80_e32756.tif
# 2091         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r082/outputs/run-no-auto-sr-scale/masks/l8olre_p089r082_d2025082620260125_dlj-dlj-strong-ge60_e32756.tif
# 2561                                     AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-auto-scale/l8olre_p089r084_d2025091120260109_dlj_e32756.tif
# 2575                        AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-baseline-include-nodata/l8olre_p089r084_d2025091120260109_dlj_e32756.tif
# 2589                                   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-forced-10000/l8olre_p089r084_d2025091120260109_dlj_e32756.tif
# 2603                               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-no-auto-sr-scale/l8olre_p089r084_d2025091120260109_dlj_e32756.tif
# 2562                                     AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-auto-scale/l8olre_p089r084_d2025091120260109_dll_e32756.tif
# 2576                        AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-baseline-include-nodata/l8olre_p089r084_d2025091120260109_dll_e32756.tif
# 2590                                   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-forced-10000/l8olre_p089r084_d2025091120260109_dll_e32756.tif
# 2604                               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-no-auto-sr-scale/l8olre_p089r084_d2025091120260109_dll_e32756.tif
# 2563                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-auto-scale/masks/l8olre_p089r084_d2025091120260109_dlj-dlj-clear-ge80_e32756.tif
# 2564               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-auto-scale/masks/l8olre_p089r084_d2025091120260109_dlj-dlj-strong-ge60_e32756.tif
# 2577   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-baseline-include-nodata/masks/l8olre_p089r084_d2025091120260109_dlj-dlj-clear-ge80_e32756.tif
# 2578  AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-baseline-include-nodata/masks/l8olre_p089r084_d2025091120260109_dlj-dlj-strong-ge60_e32756.tif
# 2591              AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-forced-10000/masks/l8olre_p089r084_d2025091120260109_dlj-dlj-clear-ge80_e32756.tif
# 2592             AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-forced-10000/masks/l8olre_p089r084_d2025091120260109_dlj-dlj-strong-ge60_e32756.tif
# 2605          AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-no-auto-sr-scale/masks/l8olre_p089r084_d2025091120260109_dlj-dlj-clear-ge80_e32756.tif
# 2606         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-no-auto-sr-scale/masks/l8olre_p089r084_d2025091120260109_dlj-dlj-strong-ge60_e32756.tif

# %% [markdown]
# ## 3. Match Queensland shapefiles to your EDS outputs
#
# Start by matching on **tile + start_date**. If that returns too few matches, inspect the keys and adjust the rule.

# %%
my_eval_rasters = my_outputs[my_outputs["product"] == MY_PRODUCT].copy()

matches = qld_df.merge(
    my_eval_rasters,
    on=["tile", "start_date"],
    suffixes=("_qld", "_my")
)

print(f"Matched {len(matches)} Queensland shapefiles to '{MY_PRODUCT}' rasters")
matches[["tile", "start_date", "date_group_qld", "date_group_my", "key_qld", "key"]].head(20)
# Out:
# Matched 41 Queensland shapefiles to 'dll' rasters
#         tile start_date     date_group_qld      date_group_my  \
# 0   p089r078   20250701  d2025070120260117  d2025070120260117
# 1   p089r078   20250701  d2025070120260117  d2025070120260117
# 2   p089r078   20250701  d2025070120260117  d2025070120260117
# 3   p089r078   20250701  d2025070120260117  d2025070120260117
# 4   p089r078   20250701  d2025070120260117  d2025070120260117
# 5   p089r078   20250701  d2025070120260117  d2025070120260117
# 6   p089r078   20250701  d2025070120260117  d2025070120260117
# 7   p089r078   20250701  d2025070120260117  d2025070120260117
# 8   p089r084   20250911  d2025091120260109  d2025091120260109
# 9   p089r084   20250911  d2025091120260109  d2025091120260109
# 10  p089r084   20250911  d2025091120260109  d2025091120260109
# 11  p089r084   20250911  d2025091120260109  d2025091120260109
# 12  p090r077   20250817  d2025081720260201  d2025081720260201
# 13  p090r077   20250817  d2025081720260201  d2025081720260201
# 14  p090r079   20251004  d2025100420260201  d2025100420260201
# 15  p090r079   20251004  d2025100420260201  d2025100420260201
# 16  p090r086   20251105  d2025110520260201  d2025110520260201
# 17  p090r090   20250614  d2025061420251121  d2025061420251121
# 18  p090r090   20250614  d2025061420251121  d2025061420251121
# 19  p090r090   20250614  d2025061420251121  d2025061420251121
#
#                                                                                                                               key_qld  \
# 0             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 1             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 2             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 3             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 4             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 5             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 6             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 7             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 8             dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.shp
# 9             dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.shp
# 10            dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.shp
# 11            dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.shp
# 12  dcceew_202602_run/lzolre_p090r077_d2025081720260201_dlwm6_completed/lzolre_p090r077_d2025081720260201_dlwm6_completed_checked.shp
# 13  dcceew_202602_run/lzolre_p090r077_d2025081720260201_dlwm6_completed/lzolre_p090r077_d2025081720260201_dlwm6_completed_checked.shp
# 14            dcceew_202602_run/lzolre_p090r079_d2025100420260201_dlwm6/lzolre_p090r079_d2025100420260201_dlwm6_completed_checked.shp
# 15            dcceew_202602_run/lzolre_p090r079_d2025100420260201_dlwm6/lzolre_p090r079_d2025100420260201_dlwm6_completed_checked.shp
# 16            dcceew_202602_run/lzolre_p090r086_d2025110520260201_dlwm5/lzolre_p090r086_d2025110520260201_dlwm5_completed_checked.shp
# 17            dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.shp
# 18            dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.shp
# 19            dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.shp
#
#                                                                                                                                             key
# 0                            AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/02/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 1    AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/p089r078_d2025070120260117/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 2                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-auto-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 3   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-baseline-include-nodata/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 4              AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-forced-10000/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 5          AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-no-auto-sr-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 6               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runs-auto-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 7            AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runsrno-auto-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 8                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-auto-scale/l8olre_p089r084_d2025091120260109_dll_e32756.tif
# 9   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-baseline-include-nodata/l8olre_p089r084_d2025091120260109_dll_e32756.tif
# 10             AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-forced-10000/l8olre_p089r084_d2025091120260109_dll_e32756.tif
# 11         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-no-auto-sr-scale/l8olre_p089r084_d2025091120260109_dll_e32756.tif
# 12   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r077/outputs/p090r077_d2025081720260201/l8olre_p090r077_d2025081720260201_dll_e32756.tif
# 13         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r077/outputs/run-no-auto-sr-scale/l8olre_p090r077_d2025081720260201_dll_e32756.tif
# 14   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r079/outputs/p090r079_d2025100420260201/l8olre_p090r079_d2025100420260201_dll_e32756.tif
# 15         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r079/outputs/run-no-auto-sr-scale/l8olre_p090r079_d2025100420260201_dll_e32756.tif
# 16   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r086/outputs/p090r086_d2025110520260201/l8olre_p090r086_d2025110520260201_dll_e32755.tif
# 17               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r090/outputs/run-auto-scale/l9olre_p090r090_d2025061420251121_dll_e32755.tif
# 18             AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r090/outputs/run-forced-10000/l9olre_p090r090_d2025061420251121_dll_e32755.tif
# 19         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r090/outputs/run-no-auto-sr-scale/l9olre_p090r090_d2025061420251121_dll_e32755.tif

# %%
# Optional: inspect one tile if you need to diagnose matching
tile_to_inspect = "p089r078"

print("Queensland shapefiles for tile:")
display(qld_df[qld_df["tile"] == tile_to_inspect][["tile", "date_group_qld", "start_date", "key_qld"]].head(20))

print("\nMy outputs for tile:")
display(my_eval_rasters[my_eval_rasters["tile"] == tile_to_inspect][["tile", "date_group_my", "start_date", "product", "key"]].head(20))
# Out:
# Queensland shapefiles for tile:
#        tile     date_group_qld start_date  \
# 0  p089r078  d2025070120260117   20250701
#
#                                                                                                                    key_qld
# 0  dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# My outputs for tile:
#          tile      date_group_my start_date product  \
# 393  p089r078  d2025070120260117   20250701     dll
# 407  p089r078  d2025070120260117   20250701     dll
# 431  p089r078  d2025070120260117   20250701     dll
# 445  p089r078  d2025070120260117   20250701     dll
# 459  p089r078  d2025070120260117   20250701     dll
# 473  p089r078  d2025070120260117   20250701     dll
# 487  p089r078  d2025070120260117   20250701     dll
# 501  p089r078  d2025070120260117   20250701     dll
#
#                                                                                                                                              key
# 393                           AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/02/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 407   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/p089r078_d2025070120260117/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 431               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-auto-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 445  AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-baseline-include-nodata/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 459             AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-forced-10000/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 473         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-no-auto-sr-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 487              AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runs-auto-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 501           AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runsrno-auto-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif

# %% [markdown]
# ## 4. Download helpers
#
# A shapefile needs the `.shp` plus sidecar files like `.dbf`, `.shx`, and `.prj`.

# %%
def download_s3_file(bucket, key, local_path):
    s3 = boto3.client("s3")
    local_path.parent.mkdir(parents=True, exist_ok=True)
    s3.download_file(bucket, key, str(local_path))


def download_shapefile_bundle(bucket, shp_key, out_dir):
    base = os.path.splitext(shp_key)[0]
    exts = [".shp", ".dbf", ".shx", ".prj", ".cpg"]

    downloaded = []
    for ext in exts:
        key = base + ext
        local_path = Path(out_dir) / Path(key).name
        try:
            download_s3_file(bucket, key, local_path)
            downloaded.append(local_path)
        except Exception:
            pass

    shp_local = Path(out_dir) / (Path(base).name + ".shp")
    return shp_local, downloaded


def download_raster(bucket, key, out_dir):
    local_path = Path(out_dir) / Path(key).name
    download_s3_file(bucket, key, local_path)
    return local_path

# %% [markdown]
# ## 5. Compare one matched pair
#
# This reads one Queensland shapefile, filters `IsClearing == 'Y'`, samples your raster inside those polygons, and calculates whether your EDS predicted clearing.
#
# You may need to adjust:
# - `MY_PRODUCT`
# - `RASTER_THRESHOLD`
# - `MIN_PROP_ABOVE_THRESHOLD`
# - the exact validation field name if it is not `IsClearing`

# %%
def polygon_raster_stats(raster_path, gdf, clearing_classes=None, classes_of_interest=None):
    """
    For each validation polygon, calculate DLL class composition.
    """
    results = []

    if clearing_classes is None:
        clearing_classes = set()

    if classes_of_interest is None:
        classes_of_interest = []

    with rasterio.open(raster_path) as src:
        nodata = src.nodata
        gdf = gdf.to_crs(src.crs)

        for idx, row in gdf.iterrows():
            geom = [mapping(row.geometry)]

            try:
                out_image, _ = mask(src, geom, crop=True)
                data = out_image[0]

                if nodata is not None:
                    data = data[data != nodata]

                data = data[np.isfinite(data)]

                res = {
                    "index": idx,
                    "pixel_count": 0,
                    "min": np.nan,
                    "mean": np.nan,
                    "max": np.nan,
                    "majority_value": np.nan,
                    "unique_values": "",
                    "prop_clearing_classes": np.nan,
                }

                for cls in classes_of_interest:
                    res[f"class_{cls}_count"] = 0
                    res[f"class_{cls}_prop"] = np.nan
                    res[f"class_{cls}_pct"] = np.nan

                if data.size == 0:
                    results.append(res)
                    continue

                data_int = data.astype(int)

                unique_vals, counts = np.unique(data_int, return_counts=True)
                count_map = dict(zip(unique_vals.tolist(), counts.tolist()))

                total_pixels = int(data_int.size)
                majority_value = int(unique_vals[np.argmax(counts)])
                unique_values_str = ",".join(map(str, unique_vals.tolist()))
                prop_clearing = float(np.mean(np.isin(data_int, list(clearing_classes))))

                res.update({
                    "pixel_count": total_pixels,
                    "min": int(np.min(data_int)),
                    "mean": float(np.mean(data_int)),
                    "max": int(np.max(data_int)),
                    "majority_value": majority_value,
                    "unique_values": unique_values_str,
                    "prop_clearing_classes": prop_clearing,
                })

                for cls in classes_of_interest:
                    cls_count = int(count_map.get(cls, 0))
                    cls_prop = cls_count / total_pixels if total_pixels > 0 else np.nan
                    res[f"class_{cls}_count"] = cls_count
                    res[f"class_{cls}_prop"] = cls_prop
                    res[f"class_{cls}_pct"] = cls_prop * 100 if pd.notna(cls_prop) else np.nan

                results.append(res)

            except Exception:
                res = {
                    "index": idx,
                    "pixel_count": 0,
                    "min": np.nan,
                    "mean": np.nan,
                    "max": np.nan,
                    "majority_value": np.nan,
                    "unique_values": "",
                    "prop_clearing_classes": np.nan,
                }

                for cls in classes_of_interest:
                    res[f"class_{cls}_count"] = 0
                    res[f"class_{cls}_prop"] = np.nan
                    res[f"class_{cls}_pct"] = np.nan

                results.append(res)

    return pd.DataFrame(results)


def find_clearing_field(gdf):
    col_map = {col.lower(): col for col in gdf.columns}

    for name in ["isclearing", "iscleared", "cleared", "clearing", "esastatus", "status"]:
        if name in col_map:
            return col_map[name]

    for lower_col, original_col in col_map.items():
        if any(token in lower_col for token in ["clear", "clearing", "esa"]):
            return original_col

    return None


def normalise_truth_value(value):
    if pd.isna(value):
        return None

    value = str(value).upper().strip()

    if value in {"Y", "YES", "TRUE", "1"}:
        return 1
    if value in {"N", "NO", "FALSE", "0"}:
        return 0

    return None


def evaluate_match(match_row):
    with tempfile.TemporaryDirectory() as tmpdir:
        shp_local, downloaded_files = download_shapefile_bundle(
            bucket=QLD_BUCKET,
            shp_key=match_row["key_qld"],
            out_dir=tmpdir
        )

        raster_local = download_raster(
            bucket=MY_BUCKET,
            key=match_row["key"],
            out_dir=tmpdir
        )

        qld_gdf = gpd.read_file(shp_local)
        clearing_field = find_clearing_field(qld_gdf)

        if clearing_field is None:
            raise ValueError(
                f"No clearing field found in shapefile. Columns were: {list(qld_gdf.columns)}"
            )

        qld_gdf["_clearing_value"] = (
            qld_gdf[clearing_field]
            .astype(str)
            .str.upper()
            .str.strip()
        )

        qld_gdf["truth"] = qld_gdf["_clearing_value"].apply(normalise_truth_value)
        qld_truth = qld_gdf[qld_gdf["truth"].notna()].copy()

        if qld_truth.empty:
            raise ValueError("No usable Y/N truth values found in shapefile.")

        stats_df = polygon_raster_stats(
            raster_local,
            qld_truth,
            clearing_classes=DLL_CLEARING_CLASSES,
            classes_of_interest=DLL_CLASSES_OF_INTEREST,
        )

        qld_eval = qld_truth.join(stats_df.set_index("index"))

        if PREDICTION_METHOD == "majority":
            qld_eval["predicted_cleared"] = qld_eval["majority_value"].isin(DLL_CLEARING_CLASSES)
        elif PREDICTION_METHOD == "proportion":
            qld_eval["predicted_cleared"] = (
                qld_eval["prop_clearing_classes"] >= MIN_PROP_TARGET_CLASS
            )
        else:
            raise ValueError(f"Unknown PREDICTION_METHOD: {PREDICTION_METHOD}")

        qld_eval["pred"] = qld_eval["predicted_cleared"].astype(int)

        valid_eval = qld_eval[qld_eval["pred"].notna() & qld_eval["truth"].notna()].copy()

        tp = int(((valid_eval["truth"] == 1) & (valid_eval["pred"] == 1)).sum())
        fn = int(((valid_eval["truth"] == 1) & (valid_eval["pred"] == 0)).sum())
        fp = int(((valid_eval["truth"] == 0) & (valid_eval["pred"] == 1)).sum())
        tn = int(((valid_eval["truth"] == 0) & (valid_eval["pred"] == 0)).sum())

        summary = {
            "tile": match_row["tile"],
            "start_date": match_row["start_date"],
            "date_group_qld": match_row.get("date_group_qld"),
            "date_group_my": match_row.get("date_group_my"),
            "key_qld": match_row.get("key_qld"),
            "key": match_row.get("key"),
            "product": match_row.get("product", MY_PRODUCT),
            "prediction_method": PREDICTION_METHOD,
            "DLL_CLEARING_CLASSES": str(sorted(DLL_CLEARING_CLASSES)),
            "MIN_PROP_TARGET_CLASS": MIN_PROP_TARGET_CLASS if PREDICTION_METHOD == "proportion" else np.nan,

            "total_truth_polygons": int(len(qld_truth)),
            "usable_polygons": int(len(valid_eval)),
            "validated_cleared_polygons": int((valid_eval["truth"] == 1).sum()),
            "validated_not_cleared_polygons": int((valid_eval["truth"] == 0).sum()),

            "tp": tp,
            "fn": fn,
            "fp": fp,
            "tn": tn,

            "detected_by_my_eds": tp,
            "missed_by_my_eds": fn,
        }

        summary["recall"] = tp / (tp + fn) if (tp + fn) else np.nan
        summary["precision"] = tp / (tp + fp) if (tp + fp) else np.nan
        summary["specificity"] = tn / (tn + fp) if (tn + fp) else np.nan
        summary["accuracy"] = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) else np.nan
        summary["f1"] = (
            2 * summary["precision"] * summary["recall"] / (summary["precision"] + summary["recall"])
            if pd.notna(summary["precision"]) and pd.notna(summary["recall"]) and (summary["precision"] + summary["recall"]) > 0
            else np.nan
        )

        return summary, qld_eval, qld_gdf

# %%
# Run one matched pair first
match_index = 1

if len(matches) == 0:
    raise ValueError("No matches found. Inspect the tile/date logic above first.")

single_summary, single_eval, single_full_gdf = evaluate_match(matches.iloc[match_index])

pd.DataFrame([single_summary])
# Out:
#        tile start_date     date_group_qld      date_group_my  \
# 0  p089r078   20250701  d2025070120260117  d2025070120260117
#
#                                                                                                                    key_qld  \
# 0  dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
#
#                                                                                                                                           key  \
# 0  AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/p089r078_d2025070120260117/l9olre_p089r078_d2025070120260117_dll_e32756.tif
#
#   product prediction_method      DLL_CLEARING_CLASSES  MIN_PROP_TARGET_CLASS  \
# 0     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
#
#    ...  fn  fp  tn  detected_by_my_eds  missed_by_my_eds  recall  precision  \
# 0  ...   1   0   0                   0                 1     0.0        NaN
#
#    specificity  accuracy  f1
# 0          NaN       0.0 NaN
#
# [1 rows x 25 columns]

# %%
print("Total polygons in shapefile:", len(single_full_gdf))

print("\nIsClearing breakdown:")
print(single_full_gdf["IsClearing"].value_counts(dropna=False))
# Out:
# Total polygons in shapefile: 7
#
# IsClearing breakdown:
# IsClearing
# u    6
# y    1
# Name: count, dtype: int64

# %%
# Inspect the evaluated polygons for the single pair, including DLL class composition
if single_eval is not None:
    inspect_cols = [
        "_clearing_value",
        "truth",
        "pixel_count",
        "min",
        "mean",
        "max",
        "majority_value",
        "unique_values",
        "prop_clearing_classes",
        "predicted_cleared",
    ]

    for cls in DLL_CLASSES_OF_INTEREST:
        inspect_cols.append(f"class_{cls}_pct")

    inspect_cols = [c for c in inspect_cols if c in single_eval.columns]
    display(single_eval[inspect_cols].head(30))
# Out:
#   _clearing_value  truth  pixel_count  min      mean  max  majority_value  \
# 4               Y    1.0          138   10  25.65942   36              10
#
#   unique_values  prop_clearing_classes  predicted_cleared  class_10_pct  \
# 4   10,34,35,36               0.637681              False     36.231884
#
#    class_34_pct  class_35_pct  class_36_pct  class_37_pct  class_38_pct  \
# 4      31.15942     29.710145      2.898551           0.0           0.0
#
#    class_39_pct
# 4           0.0

# %% [markdown]
# ## 6. Run all matched pairs
#
# This loops over all matched tile/start-date pairs and gives a summary table.

# %%
# all_summaries = []
# all_errors = []

# for idx, row in matches.iterrows():
#     try:
#         summary, _, _ = evaluate_match(
#             row,
#             raster_threshold=RASTER_THRESHOLD,
#             min_prop_above_threshold=MIN_PROP_ABOVE_THRESHOLD
#         )
#         all_summaries.append(summary)
#     except Exception as exc:
#         all_errors.append({
#             "match_index": idx,
#             "tile": row.get("tile"),
#             "start_date": row.get("start_date"),
#             "key_qld": row.get("key_qld"),
#             "key_my": row.get("key"),
#             "error": str(exc),
#         })

# results_df = pd.DataFrame(all_summaries)
# errors_df = pd.DataFrame(all_errors)

# print(f"Successful evaluations: {len(results_df)}")
# print(f"Errors: {len(errors_df)}")

# results_df.sort_values(["tile", "start_date"]).head(20)

# %%
# # Overall summary
# if not results_df.empty:
#     overall = {
#         "matched_pairs": len(results_df),
#         "validated_cleared_polygons": int(results_df["validated_cleared_polygons"].sum()),
#         "detected_by_my_eds": int(results_df["detected_by_my_eds"].sum()),
#         "missed_by_my_eds": int(results_df["missed_by_my_eds"].sum()),
#     }
#     overall["overall_recall"] = (
#         overall["detected_by_my_eds"] / overall["validated_cleared_polygons"]
#         if overall["validated_cleared_polygons"] else np.nan
#     )

#     display(pd.DataFrame([overall]))

# if not errors_df.empty:
#     display(errors_df.head(20))

# %% [markdown]
# ## 7. Export results (for later concatenation)

# %%
# from pathlib import Path
# import datetime

# # Create output folder
# output_dir = Path("validation_outputs")
# output_dir.mkdir(exist_ok=True)

# # Timestamp to keep runs separate
# timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# # ---- Export per-polygon evaluation (most detailed) ----
# if 'results_df' in globals() and not results_df.empty:
#     results_path = output_dir / f"eds_validation_summary_{timestamp}.csv"
#     results_df.to_csv(results_path, index=False)
#     print(f"Saved summary results to: {results_path}")

# # ---- Export overall summary ----
# if 'overall' in globals():
#     overall_df = pd.DataFrame([overall])
#     overall_path = output_dir / f"eds_validation_overall_{timestamp}.csv"
#     overall_df.to_csv(overall_path, index=False)
#     print(f"Saved overall summary to: {overall_path}")

# # ---- Export errors (if any) ----
# if 'errors_df' in globals() and not errors_df.empty:
#     errors_path = output_dir / f"eds_validation_errors_{timestamp}.csv"
#     errors_df.to_csv(errors_path, index=False)
#     print(f"Saved errors to: {errors_path}")

# # ---- OPTIONAL: export detailed polygon-level data ----
# if 'single_eval' in globals() and single_eval is not None:
#     detailed_path = output_dir / f"eds_validation_detailed_{timestamp}.csv"
#     single_eval.to_csv(detailed_path, index=False)
#     print(f"Saved detailed polygon results to: {detailed_path}")

# %%
all_summaries = []
all_eval_parts = []
all_errors = []

for i, match_row in matches.iterrows():
    try:
        summary, eval_df, full_gdf = evaluate_match(match_row)
        all_summaries.append(summary)

        if eval_df is not None and not eval_df.empty:
            eval_df = eval_df.copy()

            # Put all polygon outputs into a common CRS before concatenation
            if hasattr(eval_df, "to_crs") and getattr(eval_df, "crs", None) is not None:
                eval_df = eval_df.to_crs(COMMON_CRS)

            eval_df["tile"] = match_row["tile"]
            eval_df["start_date"] = match_row["start_date"]
            eval_df["date_group_qld"] = match_row.get("date_group_qld")
            eval_df["date_group_my"] = match_row.get("date_group_my")
            eval_df["key_qld"] = match_row.get("key_qld")
            eval_df["key"] = match_row.get("key")

            all_eval_parts.append(eval_df)

    except Exception as e:
        all_errors.append({
            "match_row_index": i,
            "tile": match_row.get("tile"),
            "start_date": match_row.get("start_date"),
            "date_group_qld": match_row.get("date_group_qld"),
            "date_group_my": match_row.get("date_group_my"),
            "key_qld": match_row.get("key_qld"),
            "key": match_row.get("key"),
            "error": str(e),
        })

results_df = pd.DataFrame(all_summaries)
errors_df = pd.DataFrame(all_errors)

if all_eval_parts:
    all_eval_df = pd.concat(all_eval_parts, ignore_index=True)

    if "geometry" in all_eval_df.columns:
        all_eval_csv_df = all_eval_df.drop(columns=["geometry"]).copy()
    else:
        all_eval_csv_df = all_eval_df.copy()
else:
    all_eval_df = pd.DataFrame()
    all_eval_csv_df = pd.DataFrame()

print(f"Successful evaluations: {len(results_df)}")
print(f"Errors: {len(errors_df)}")

display(results_df.sort_values(["tile", "start_date"]))
if not errors_df.empty:
    display(errors_df)
# Out:
# Successful evaluations: 41
# Errors: 0
#         tile start_date     date_group_qld      date_group_my  \
# 0   p089r078   20250701  d2025070120260117  d2025070120260117
# 1   p089r078   20250701  d2025070120260117  d2025070120260117
# 2   p089r078   20250701  d2025070120260117  d2025070120260117
# 3   p089r078   20250701  d2025070120260117  d2025070120260117
# 4   p089r078   20250701  d2025070120260117  d2025070120260117
# 5   p089r078   20250701  d2025070120260117  d2025070120260117
# 6   p089r078   20250701  d2025070120260117  d2025070120260117
# 7   p089r078   20250701  d2025070120260117  d2025070120260117
# 8   p089r084   20250911  d2025091120260109  d2025091120260109
# 9   p089r084   20250911  d2025091120260109  d2025091120260109
# 10  p089r084   20250911  d2025091120260109  d2025091120260109
# 11  p089r084   20250911  d2025091120260109  d2025091120260109
# 12  p090r077   20250817  d2025081720260201  d2025081720260201
# 13  p090r077   20250817  d2025081720260201  d2025081720260201
# 14  p090r079   20251004  d2025100420260201  d2025100420260201
# 15  p090r079   20251004  d2025100420260201  d2025100420260201
# 16  p090r086   20251105  d2025110520260201  d2025110520260201
# 17  p090r090   20250614  d2025061420251121  d2025061420251121
# 18  p090r090   20250614  d2025061420251121  d2025061420251121
# 19  p090r090   20250614  d2025061420251121  d2025061420251121
# 20  p091r076   20250816  d2025081620260131  d2025081620260131
# 21  p091r077   20250917  d2025091720260131  d2025091720260131
# 22  p092r076   20251002  d2025100220260122  d2025100220260122
# 23  p092r077   20251128  d2025112820260123  d2025112820260123
# 24  p092r088   20250731  d2025073120260123  d2025073120260123
# 25  p093r075   20251018  d2025101820260122  d2025101820260122
# 26  p093r076   20251002  d2025100220260130  d2025100220260130
# 27  p093r077   20250924  d2025092420260130  d2025092420260130
# 28  p094r077   20251118  d2025111820260206  d2025111820260206
# 29  p094r087   20250814  d2025081420260105  d2025081420260105
# 30  p095r073   20250930  d2025093020251211  d2025093020251211
# 31  p096r086   20251015  d2025101520251218  d2025101520251218
# 32  p097r074   20250904  d2025090420260110  d2025090420260110
# 33  p099r069   20250825  d2025082520251215  d2025082520251215
# 34  p102r074   20250923  d2025092320260121  d2025092320260121
# 35  p104r070   20250820  d2025082020260111  d2025082020260111
# 36  p104r071   20250820  d2025082020260111  d2025082020260111
# 37  p112r076   20250929  d2025092920260204  d2025092920260204
# 38  p112r076   20250929  d2025092920260204  d2025092920260204
# 39  p112r076   20250929  d2025092920260204  d2025092920260204
# 40  p112r076   20250929  d2025092920260204  d2025092920260204
#
#                                                                                                                               key_qld  \
# 0             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 1             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 2             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 3             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 4             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 5             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 6             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 7             dcceew_202602_run/lzolre_p089r078_d2025070120260117_dlwm6/lzolre_p089r078_d2025070120260117_dlwm6_completed_checked.shp
# 8             dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.shp
# 9             dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.shp
# 10            dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.shp
# 11            dcceew_202602_run/lzolre_p089r084_d2025091120260109_dlwm6/lzolre_p089r084_d2025091120260109_dlwm6_completed_checked.shp
# 12  dcceew_202602_run/lzolre_p090r077_d2025081720260201_dlwm6_completed/lzolre_p090r077_d2025081720260201_dlwm6_completed_checked.shp
# 13  dcceew_202602_run/lzolre_p090r077_d2025081720260201_dlwm6_completed/lzolre_p090r077_d2025081720260201_dlwm6_completed_checked.shp
# 14            dcceew_202602_run/lzolre_p090r079_d2025100420260201_dlwm6/lzolre_p090r079_d2025100420260201_dlwm6_completed_checked.shp
# 15            dcceew_202602_run/lzolre_p090r079_d2025100420260201_dlwm6/lzolre_p090r079_d2025100420260201_dlwm6_completed_checked.shp
# 16            dcceew_202602_run/lzolre_p090r086_d2025110520260201_dlwm5/lzolre_p090r086_d2025110520260201_dlwm5_completed_checked.shp
# 17            dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.shp
# 18            dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.shp
# 19            dcceew_202602_run/lzolre_p090r090_d2025061420251121_dlwm5/lzolre_p090r090_d2025061420251121_dlwm5_completed_checked.shp
# 20            dcceew_202602_run/lzolre_p091r076_d2025081620260131_dlwm6/lzolre_p091r076_d2025081620260131_dlwm6_completed_checked.shp
# 21            dcceew_202602_run/lzolre_p091r077_d2025091720260131_dlwm6/lzolre_p091r077_d2025091720260131_dlwm6_completed_checked.shp
# 22            dcceew_202602_run/lzolre_p092r076_d2025100220260122_dlwm5/lzolre_p092r076_d2025100220260122_dlwm5_completed_checked.shp
# 23            dcceew_202602_run/lzolre_p092r077_d2025112820260123_dlwm5/lzolre_p092r077_d2025112820260123_dlwm5_completed_checked.shp
# 24            dcceew_202602_run/lzolre_p092r088_d2025073120260123_dlwm5/lzolre_p092r088_d2025073120260123_dlwm5_completed_checked.shp
# 25            dcceew_202602_run/lzolre_p093r075_d2025101820260122_dlwm5/lzolre_p093r075_d2025101820260122_dlwm5_completed_checked.shp
# 26            dcceew_202602_run/lzolre_p093r076_d2025100220260130_dlwm5/lzolre_p093r076_d2025100220260130_dlwm5_completed_checked.shp
# 27  dcceew_202602_run/lzolre_p093r077_d2025092420260130_dlwm5_completed/lzolre_p093r077_d2025092420260130_dlwm5_completed_checked.shp
# 28            dcceew_202602_run/lzolre_p094r077_d2025111820260206_dlwm5/lzolre_p094r077_d2025111820260206_dlwm5_completed_checked.shp
# 29            dcceew_202602_run/lzolre_p094r087_d2025081420260105_dlwm4/lzolre_p094r087_d2025081420260105_dlwm4_completed_checked.shp
# 30            dcceew_202602_run/lzolre_p095r073_d2025093020251211_dlwm5/lzolre_p095r073_d2025093020251211_dlwm5_completed_checked.shp
# 31            dcceew_202602_run/lzolre_p096r086_d2025101520251218_dlwm4/lzolre_p096r086_d2025101520251218_dlwm4_completed_checked.shp
# 32            dcceew_202602_run/lzolre_p097r074_d2025090420260110_dlwm4/lzolre_p097r074_d2025090420260110_dlwm4_completed_checked.shp
# 33            dcceew_202602_run/lzolre_p099r069_d2025082520251215_dlwm4/lzolre_p099r069_d2025082520251215_dlwm4_completed_checked.shp
# 34            dcceew_202602_run/lzolre_p102r074_d2025092320260121_dlwm3/lzolre_p102r074_d2025092320260121_dlwm3_completed_checked.shp
# 35            dcceew_202602_run/lzolre_p104r070_d2025082020260111_dlwm3/lzolre_p104r070_d2025082020260111_dlwm3_completed_checked.shp
# 36            dcceew_202602_run/lzolre_p104r071_d2025082020260111_dlwm3/lzolre_p104r071_d2025082020260111_dlwm3_completed_checked.shp
# 37            dcceew_202602_run/lzolre_p112r076_d2025092920260204_dlwm0/lzolre_p112r076_d2025092920260204_dlwm0_completed_checked.shp
# 38            dcceew_202602_run/lzolre_p112r076_d2025092920260204_dlwm0/lzolre_p112r076_d2025092920260204_dlwm0_completed_checked.shp
# 39            dcceew_202602_run/lzolre_p112r076_d2025092920260204_dlwm0/lzolre_p112r076_d2025092920260204_dlwm0_completed_checked.shp
# 40            dcceew_202602_run/lzolre_p112r076_d2025092920260204_dlwm0/lzolre_p112r076_d2025092920260204_dlwm0_completed_checked.shp
#
#                                                                                                                                             key  \
# 0                            AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/02/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 1    AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/p089r078_d2025070120260117/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 2                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-auto-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 3   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-baseline-include-nodata/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 4              AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-forced-10000/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 5          AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/run-no-auto-sr-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 6               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runs-auto-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 7            AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r078/outputs/runsrno-auto-scale/l9olre_p089r078_d2025070120260117_dll_e32756.tif
# 8                AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-auto-scale/l8olre_p089r084_d2025091120260109_dll_e32756.tif
# 9   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-baseline-include-nodata/l8olre_p089r084_d2025091120260109_dll_e32756.tif
# 10             AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-forced-10000/l8olre_p089r084_d2025091120260109_dll_e32756.tif
# 11         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r084/outputs/run-no-auto-sr-scale/l8olre_p089r084_d2025091120260109_dll_e32756.tif
# 12   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r077/outputs/p090r077_d2025081720260201/l8olre_p090r077_d2025081720260201_dll_e32756.tif
# 13         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r077/outputs/run-no-auto-sr-scale/l8olre_p090r077_d2025081720260201_dll_e32756.tif
# 14   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r079/outputs/p090r079_d2025100420260201/l8olre_p090r079_d2025100420260201_dll_e32756.tif
# 15         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r079/outputs/run-no-auto-sr-scale/l8olre_p090r079_d2025100420260201_dll_e32756.tif
# 16   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r086/outputs/p090r086_d2025110520260201/l8olre_p090r086_d2025110520260201_dll_e32755.tif
# 17               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r090/outputs/run-auto-scale/l9olre_p090r090_d2025061420251121_dll_e32755.tif
# 18             AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r090/outputs/run-forced-10000/l9olre_p090r090_d2025061420251121_dll_e32755.tif
# 19         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p090r090/outputs/run-no-auto-sr-scale/l9olre_p090r090_d2025061420251121_dll_e32755.tif
# 20   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p091r076/outputs/p091r076_d2025081620260131/l9olre_p091r076_d2025081620260131_dll_e32756.tif
# 21   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p091r077/outputs/p091r077_d2025091720260131/l9olre_p091r077_d2025091720260131_dll_e32756.tif
# 22   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p092r076/outputs/p092r076_d2025100220260122/l9olre_p092r076_d2025100220260122_dll_e32755.tif
# 23   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p092r077/outputs/p092r077_d2025112820260123/l9olre_p092r077_d2025112820260123_dll_e32755.tif
# 24   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p092r088/outputs/p092r088_d2025073120260123/l9olre_p092r088_d2025073120260123_dll_e32755.tif
# 25   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p093r075/outputs/p093r075_d2025101820260122/l8olre_p093r075_d2025101820260122_dll_e32755.tif
# 26   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p093r076/outputs/p093r076_d2025100220260130/l9olre_p093r076_d2025100220260130_dll_e32755.tif
# 27   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p093r077/outputs/p093r077_d2025092420260130/l9olre_p093r077_d2025092420260130_dll_e32755.tif
# 28   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p094r077/outputs/p094r077_d2025111820260206/l9olre_p094r077_d2025111820260206_dll_e32755.tif
# 29   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p094r087/outputs/p094r087_d2025081420260105/l9olre_p094r087_d2025081420260105_dll_e32754.tif
# 30   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p095r073/outputs/p095r073_d2025093020251211/l9olre_p095r073_d2025093020251211_dll_e32755.tif
# 31   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p096r086/outputs/p096r086_d2025101520251218/l9olre_p096r086_d2025101520251218_dll_e32754.tif
# 32   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p097r074/outputs/p097r074_d2025090420260110/l9olre_p097r074_d2025090420260110_dll_e32754.tif
# 33   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p099r069/outputs/p099r069_d2025082520251215/l8olre_p099r069_d2025082520251215_dll_e32754.tif
# 34   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p102r074/outputs/p102r074_d2025092320260121/l8olre_p102r074_d2025092320260121_dll_e32753.tif
# 35   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p104r070/outputs/p104r070_d2025082020260111/l9olre_p104r070_d2025082020260111_dll_e32753.tif
# 36   AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p104r071/outputs/p104r071_d2025082020260111/l9olre_p104r071_d2025082020260111_dll_e32753.tif
# 37               AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p112r076/outputs/run-auto-scale/l9olre_p112r076_d2025092920260204_dll_e32750.tif
# 38  AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p112r076/outputs/run-baseline-include-nodata/l9olre_p112r076_d2025092920260204_dll_e32750.tif
# 39             AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p112r076/outputs/run-forced-10000/l9olre_p112r076_d2025092920260204_dll_e32750.tif
# 40         AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p112r076/outputs/run-no-auto-sr-scale/l9olre_p112r076_d2025092920260204_dll_e32750.tif
#
#    product prediction_method      DLL_CLEARING_CLASSES  MIN_PROP_TARGET_CLASS  \
# 0      dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 1      dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 2      dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 3      dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 4      dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 5      dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 6      dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 7      dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 8      dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 9      dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 10     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 11     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 12     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 13     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 14     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 15     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 16     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 17     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 18     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 19     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 20     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 21     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 22     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 23     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 24     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 25     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 26     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 27     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 28     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 29     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 30     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 31     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 32     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 33     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 34     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 35     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 36     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 37     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 38     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 39     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
# 40     dll          majority  [34, 35, 36, 37, 38, 39]                    NaN
#
#     ...  fn  fp  tn  detected_by_my_eds  missed_by_my_eds    recall  \
# 0   ...   0   0   0                   1                 0  1.000000
# 1   ...   1   0   0                   0                 1  0.000000
# 2   ...   1   0   0                   0                 1  0.000000
# 3   ...   1   0   0                   0                 1  0.000000
# 4   ...   1   0   0                   0                 1  0.000000
# 5   ...   0   0   0                   1                 0  1.000000
# 6   ...   1   0   0                   0                 1  0.000000
# 7   ...   0   0   0                   1                 0  1.000000
# 8   ...   2   0   0                   0                 2  0.000000
# 9   ...   2   0   0                   0                 2  0.000000
# 10  ...   2   0   0                   0                 2  0.000000
# 11  ...   0   0   0                   2                 0  1.000000
# 12  ...   0   0   0                  14                 0  1.000000
# 13  ...   0   0   0                  14                 0  1.000000
# 14  ...   1   0   0                   9                 1  0.900000
# 15  ...   0   0   0                  10                 0  1.000000
# 16  ...   7   0   0                  10                 7  0.588235
# 17  ...  33   0   0                  24                33  0.421053
# 18  ...  33   0   0                  24                33  0.421053
# 19  ...  29   0   0                  28                29  0.491228
# 20  ...   0   0   0                   7                 0  1.000000
# 21  ...   5   0   0                  11                 5  0.687500
# 22  ...   0   2   0                   3                 0  1.000000
# 23  ...   0   0   0                   3                 0  1.000000
# 24  ...  15   0   0                  36                15  0.705882
# 25  ...   0   0   0                   4                 0  1.000000
# 26  ...   0   0   0                   3                 0  1.000000
# 27  ...   0   0   0                   3                 0  1.000000
# 28  ...   0   0   0                   1                 0  1.000000
# 29  ...   0   3   0                   3                 0  1.000000
# 30  ...   0   0   0                   1                 0  1.000000
# 31  ...   0   0   0                   3                 0  1.000000
# 32  ...   0   1   1                   0                 0       NaN
# 33  ...   1   0   0                  12                 1  0.923077
# 34  ...   0   0   0                   2                 0  1.000000
# 35  ...   0   0   0                   2                 0  1.000000
# 36  ...   0   0   0                   1                 0  1.000000
# 37  ...   2   0   0                  17                 2  0.894737
# 38  ...   2   0   0                  17                 2  0.894737
# 39  ...   2   0   0                  17                 2  0.894737
# 40  ...   0   0   0                  19                 0  1.000000
#
#     precision  specificity  accuracy        f1
# 0         1.0          NaN  1.000000  1.000000
# 1         NaN          NaN  0.000000       NaN
# 2         NaN          NaN  0.000000       NaN
# 3         NaN          NaN  0.000000       NaN
# 4         NaN          NaN  0.000000       NaN
# 5         1.0          NaN  1.000000  1.000000
# 6         NaN          NaN  0.000000       NaN
# 7         1.0          NaN  1.000000  1.000000
# 8         NaN          NaN  0.000000       NaN
# 9         NaN          NaN  0.000000       NaN
# 10        NaN          NaN  0.000000       NaN
# 11        1.0          NaN  1.000000  1.000000
# 12        1.0          NaN  1.000000  1.000000
# 13        1.0          NaN  1.000000  1.000000
# 14        1.0          NaN  0.900000  0.947368
# 15        1.0          NaN  1.000000  1.000000
# 16        1.0          NaN  0.588235  0.740741
# 17        1.0          NaN  0.421053  0.592593
# 18        1.0          NaN  0.421053  0.592593
# 19        1.0          NaN  0.491228  0.658824
# 20        1.0          NaN  1.000000  1.000000
# 21        1.0          NaN  0.687500  0.814815
# 22        0.6          0.0  0.600000  0.750000
# 23        1.0          NaN  1.000000  1.000000
# 24        1.0          NaN  0.705882  0.827586
# 25        1.0          NaN  1.000000  1.000000
# 26        1.0          NaN  1.000000  1.000000
# 27        1.0          NaN  1.000000  1.000000
# 28        1.0          NaN  1.000000  1.000000
# 29        0.5          0.0  0.500000  0.666667
# 30        1.0          NaN  1.000000  1.000000
# 31        1.0          NaN  1.000000  1.000000
# 32        0.0          0.5  0.500000       NaN
# 33        1.0          NaN  0.923077  0.960000
# 34        1.0          NaN  1.000000  1.000000
# 35        1.0          NaN  1.000000  1.000000
# 36        1.0          NaN  1.000000  1.000000
# 37        1.0          NaN  0.894737  0.944444
# 38        1.0          NaN  0.894737  0.944444
# 39        1.0          NaN  0.894737  0.944444
# 40        1.0          NaN  1.000000  1.000000
#
# [41 rows x 25 columns]

# %% [markdown]
# ## 6b. Polygon class composition

# %%
# Polygon class composition table
# This is the main table for model refinement.
# It shows the percentage of each DLL class inside each QLD validation polygon.

if 'all_eval_csv_df' in globals() and not all_eval_csv_df.empty:
    composition_cols = [
        "tile",
        "start_date",
        "_clearing_value",
        "truth",
        "pixel_count",
        "majority_value",
        "unique_values",
        "prop_clearing_classes",
        "predicted_cleared",
    ]

    for cls in DLL_CLASSES_OF_INTEREST:
        composition_cols.extend([
            f"class_{cls}_count",
            f"class_{cls}_prop",
            f"class_{cls}_pct",
        ])

    composition_cols = [c for c in composition_cols if c in all_eval_csv_df.columns]
    polygon_composition_df = all_eval_csv_df[composition_cols].copy()

    display(polygon_composition_df.head(30))
else:
    polygon_composition_df = pd.DataFrame()
    print("No polygon-level results found yet. Run Section 6 first.")
# Out:
#         tile start_date _clearing_value  truth  pixel_count  majority_value  \
# 0   p089r078   20250701               Y    1.0          138              39
# 1   p089r078   20250701               Y    1.0          138              10
# 2   p089r078   20250701               Y    1.0          138              10
# 3   p089r078   20250701               Y    1.0          138              10
# 4   p089r078   20250701               Y    1.0          138              10
# 5   p089r078   20250701               Y    1.0          138              39
# 6   p089r078   20250701               Y    1.0          138              10
# 7   p089r078   20250701               Y    1.0          138              39
# 8   p089r084   20250911               Y    1.0          390              10
# 9   p089r084   20250911               Y    1.0          133              10
# 10  p089r084   20250911               Y    1.0          390              10
# 11  p089r084   20250911               Y    1.0          133              10
# 12  p089r084   20250911               Y    1.0          390              10
# 13  p089r084   20250911               Y    1.0          133              10
# 14  p089r084   20250911               Y    1.0          390              39
# 15  p089r084   20250911               Y    1.0          133              39
# 16  p090r077   20250817               Y    1.0          197              39
# 17  p090r077   20250817               Y    1.0          179              39
# 18  p090r077   20250817               Y    1.0          141              34
# 19  p090r077   20250817               Y    1.0          137              34
# 20  p090r077   20250817               Y    1.0          127              39
# 21  p090r077   20250817               Y    1.0          123              34
# 22  p090r077   20250817               Y    1.0           97              39
# 23  p090r077   20250817               Y    1.0           33              39
# 24  p090r077   20250817               Y    1.0          221              39
# 25  p090r077   20250817               Y    1.0           74              34
# 26  p090r077   20250817               Y    1.0            9              34
# 27  p090r077   20250817               Y    1.0           51              34
# 28  p090r077   20250817               Y    1.0           23              34
# 29  p090r077   20250817               Y    1.0           28              34
#
#              unique_values  prop_clearing_classes  predicted_cleared  \
# 0     10,34,35,36,37,38,39               0.971014               True
# 1              10,34,35,36               0.637681              False
# 2            3,10,34,35,36               0.615942              False
# 3            3,10,34,35,36               0.630435              False
# 4            3,10,34,35,36               0.615942              False
# 5   3,10,34,35,36,37,38,39               0.942029               True
# 6            3,10,34,35,36               0.630435              False
# 7   3,10,34,35,36,37,38,39               0.942029               True
# 8         3,10,34,35,36,37               0.435897              False
# 9            3,10,34,35,36               0.413534              False
# 10        3,10,34,35,36,37               0.351282              False
# 11             10,34,35,36               0.165414              False
# 12        3,10,34,35,36,37               0.435897              False
# 13           3,10,34,35,36               0.413534              False
# 14  3,10,34,35,36,37,38,39               0.723077               True
# 15  3,10,34,35,36,37,38,39               0.736842               True
# 16        3,10,34,36,37,39               0.857868               True
# 17        3,34,35,37,38,39               0.988827               True
# 18  3,10,34,35,36,37,38,39               0.723404               True
# 19        3,10,34,35,36,39               0.518248               True
# 20       34,35,36,37,38,39               1.000000               True
# 21  3,10,34,35,36,37,38,39               0.878049               True
# 22  3,10,34,35,36,37,38,39               0.814433               True
# 23             36,37,38,39               1.000000               True
# 24  3,10,34,35,36,37,38,39               0.769231               True
# 25                10,34,35               0.797297               True
# 26              3,34,36,39               0.888889               True
# 27     3,10,34,36,37,38,39               0.921569               True
# 28                10,34,35               0.826087               True
# 29     3,10,34,36,37,38,39               0.750000               True
#
#     class_10_count  ...  class_36_pct  class_37_count  class_37_prop  \
# 0                4  ...      2.173913               9       0.065217
# 1               50  ...      2.898551               0       0.000000
# 2               52  ...      2.898551               0       0.000000
# 3               50  ...      2.898551               0       0.000000
# 4               52  ...      2.898551               0       0.000000
# 5                7  ...      4.347826               3       0.021739
# 6               50  ...      2.898551               0       0.000000
# 7                7  ...      4.347826               5       0.036232
# 8              213  ...     10.256410              14       0.035897
# 9               75  ...      1.503759               0       0.000000
# 10             247  ...      3.846154              11       0.028205
# 11             111  ...      1.503759               0       0.000000
# 12             213  ...     10.256410              14       0.035897
# 13              75  ...      1.503759               0       0.000000
# 14             101  ...      2.820513              11       0.028205
# 15              32  ...      3.007519              13       0.097744
# 16              26  ...      1.522843               2       0.010152
# 17               0  ...      0.000000               2       0.011173
# 18              36  ...      1.418440               1       0.007092
# 19              62  ...      1.459854               0       0.000000
# 20               0  ...      9.448819              10       0.078740
# 21              13  ...     12.195122               4       0.032520
# 22              17  ...      5.154639               6       0.061856
# 23               0  ...      3.030303               1       0.030303
# 24              36  ...      8.144796               4       0.018100
# 25              15  ...      0.000000               0       0.000000
# 26               0  ...     11.111111               0       0.000000
# 27               2  ...      1.960784               3       0.058824
# 28               4  ...      0.000000               0       0.000000
# 29               5  ...      7.142857               6       0.214286
#
#     class_37_pct  class_38_count  class_38_prop  class_38_pct  class_39_count  \
# 0       6.521739               8       0.057971      5.797101             104
# 1       0.000000               0       0.000000      0.000000               0
# 2       0.000000               0       0.000000      0.000000               0
# 3       0.000000               0       0.000000      0.000000               0
# 4       0.000000               0       0.000000      0.000000               0
# 5       2.173913               7       0.050725      5.072464              99
# 6       0.000000               0       0.000000      0.000000               0
# 7       3.623188               7       0.050725      5.072464              99
# 8       3.589744               0       0.000000      0.000000               0
# 9       0.000000               0       0.000000      0.000000               0
# 10      2.820513               0       0.000000      0.000000               0
# 11      0.000000               0       0.000000      0.000000               0
# 12      3.589744               0       0.000000      0.000000               0
# 13      0.000000               0       0.000000      0.000000               0
# 14      2.820513              19       0.048718      4.871795             144
# 15      9.774436              12       0.090226      9.022556              54
# 16      1.015228               0       0.000000      0.000000             157
# 17      1.117318               1       0.005587      0.558659             169
# 18      0.709220               3       0.021277      2.127660              14
# 19      0.000000               0       0.000000      0.000000               5
# 20      7.874016               8       0.062992      6.299213              68
# 21      3.252033               1       0.008130      0.813008               5
# 22      6.185567               5       0.051546      5.154639              58
# 23      3.030303               1       0.030303      3.030303              30
# 24      1.809955               6       0.027149      2.714932              71
# 25      0.000000               0       0.000000      0.000000               0
# 26      0.000000               0       0.000000      0.000000               2
# 27      5.882353               7       0.137255     13.725490               7
# 28      0.000000               0       0.000000      0.000000               0
# 29     21.428571               2       0.071429      7.142857               1
#
#     class_39_prop  class_39_pct
# 0        0.753623     75.362319
# 1        0.000000      0.000000
# 2        0.000000      0.000000
# 3        0.000000      0.000000
# 4        0.000000      0.000000
# 5        0.717391     71.739130
# 6        0.000000      0.000000
# 7        0.717391     71.739130
# 8        0.000000      0.000000
# 9        0.000000      0.000000
# 10       0.000000      0.000000
# 11       0.000000      0.000000
# 12       0.000000      0.000000
# 13       0.000000      0.000000
# 14       0.369231     36.923077
# 15       0.406015     40.601504
# 16       0.796954     79.695431
# 17       0.944134     94.413408
# 18       0.099291      9.929078
# 19       0.036496      3.649635
# 20       0.535433     53.543307
# 21       0.040650      4.065041
# 22       0.597938     59.793814
# 23       0.909091     90.909091
# 24       0.321267     32.126697
# 25       0.000000      0.000000
# 26       0.222222     22.222222
# 27       0.137255     13.725490
# 28       0.000000      0.000000
# 29       0.035714      3.571429
#
# [30 rows x 30 columns]

# %%
from pathlib import Path
import datetime

output_dir = Path("validation_outputs")
output_dir.mkdir(exist_ok=True)

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

method_label = (
    f"{PREDICTION_METHOD}_prop{str(MIN_PROP_TARGET_CLASS).replace('.', 'p')}"
    if PREDICTION_METHOD == "proportion"
    else PREDICTION_METHOD
)

if 'results_df' in globals() and not results_df.empty:
    results_path = output_dir / f"eds_validation_summary_{method_label}_{timestamp}.csv"
    results_df.to_csv(results_path, index=False)
    print(f"Saved summary results: {results_path}")

if 'all_eval_csv_df' in globals() and not all_eval_csv_df.empty:
    eval_path = output_dir / f"eds_validation_polygon_level_{method_label}_{timestamp}.csv"
    all_eval_csv_df.to_csv(eval_path, index=False)
    print(f"Saved polygon-level CSV results: {eval_path}")

if 'polygon_composition_df' in globals() and not polygon_composition_df.empty:
    composition_path = output_dir / f"eds_validation_polygon_composition_{method_label}_{timestamp}.csv"
    polygon_composition_df.to_csv(composition_path, index=False)
    print(f"Saved polygon class composition: {composition_path}")

if 'all_eval_df' in globals() and not all_eval_df.empty and "geometry" in all_eval_df.columns:
    gpkg_path = output_dir / f"eds_validation_polygon_level_{method_label}_{timestamp}.gpkg"
    all_eval_df.to_file(gpkg_path, driver="GPKG")
    print(f"Saved polygon-level spatial results: {gpkg_path}")

if 'errors_df' in globals() and not errors_df.empty:
    errors_path = output_dir / f"eds_validation_errors_{method_label}_{timestamp}.csv"
    errors_df.to_csv(errors_path, index=False)
    print(f"Saved errors: {errors_path}")
# Out:
# Saved summary results: validation_outputs/eds_validation_summary_majority_20260505_231236.csv
# Saved polygon-level CSV results: validation_outputs/eds_validation_polygon_level_majority_20260505_231236.csv
# Saved polygon class composition: validation_outputs/eds_validation_polygon_composition_majority_20260505_231236.csv
# Saved polygon-level spatial results: validation_outputs/eds_validation_polygon_level_majority_20260505_231236.gpkg

# %% [markdown]
# ## 8. Notes
#
# This notebook uses the **DLL classified raster**.
#
# DLL class interpretation used here:
#
# - `10` = no change
# - `34, 35, 36, 37, 38, 39` = clearing classes at different confidence levels
#
# Prediction method in this notebook:
#
# - `majority`
#
# The polygon composition table records the percentage of each DLL class within each Queensland validation polygon.

# %%
# Optional check: inspect the single-pair class values
if 'single_eval' in globals() and not single_eval.empty:
    display(single_eval[[
        "truth", "_clearing_value", "pixel_count",
        "majority_value", "prop_clearing_classes",
        "unique_values"
    ]].head(30))
# Out:
#    truth _clearing_value  pixel_count  majority_value  prop_clearing_classes  \
# 4    1.0               Y          138              10               0.637681
#
#   unique_values
# 4   10,34,35,36

# %%
# Optional overall summary
if 'results_df' in globals() and not results_df.empty:
    overall = {
        "matched_pairs": int(len(results_df)),
        "validated_cleared_polygons": int(results_df["validated_cleared_polygons"].sum()),
        "validated_not_cleared_polygons": int(results_df["validated_not_cleared_polygons"].sum()),
        "tp": int(results_df["tp"].sum()),
        "fn": int(results_df["fn"].sum()),
        "fp": int(results_df["fp"].sum()),
        "tn": int(results_df["tn"].sum()),
    }

    overall["recall"] = overall["tp"] / (overall["tp"] + overall["fn"]) if (overall["tp"] + overall["fn"]) else np.nan
    overall["precision"] = overall["tp"] / (overall["tp"] + overall["fp"]) if (overall["tp"] + overall["fp"]) else np.nan
    overall["specificity"] = overall["tn"] / (overall["tn"] + overall["fp"]) if (overall["tn"] + overall["fp"]) else np.nan
    overall["accuracy"] = (
        (overall["tp"] + overall["tn"]) /
        (overall["tp"] + overall["tn"] + overall["fp"] + overall["fn"])
        if (overall["tp"] + overall["tn"] + overall["fp"] + overall["fn"]) else np.nan
    )
    overall["f1"] = (
        2 * overall["precision"] * overall["recall"] / (overall["precision"] + overall["recall"])
        if pd.notna(overall["precision"]) and pd.notna(overall["recall"]) and (overall["precision"] + overall["recall"]) > 0
        else np.nan
    )

    display(pd.DataFrame([overall]))
# Out:
#    matched_pairs  validated_cleared_polygons  validated_not_cleared_polygons  \
# 0             41                         444                               7
#
#     tp   fn  fp  tn    recall  precision  specificity  accuracy        f1
# 0  303  141   6   1  0.682432   0.980583     0.142857  0.674058  0.804781
