# %%
import geopandas as gpd

path = "/vsis3/dcceew-rs-data/dcceew_202602_run/lzolre_p090r077_d2025081720260201_dlwm6_completed/lzolre_p090r077_d2025081720260201_dlwm6_completed_checked.shp"

gdf = gpd.read_file(path)

print(gdf.columns)
print(gdf.head())
# Out:
# Index(['Area_ha', 'EsaStatus', 'IsClearing', 'Notes', 'Project', 'geometry'], dtype='object')
#    Area_ha EsaStatus IsClearing                          Notes Project  \
# 0     3220        VI          u  appears to be seasonal change  dcceew
# 1      573      None          u                           None  dcceew
# 2      518      None          u                           None  dcceew
# 3      475      None          u                           None  dcceew
# 4      371      None          u                           None  dcceew
#
#                                             geometry
# 0  MULTIPOLYGON (((358575 7225405, 358755 7225405...
# 1  MULTIPOLYGON (((374055 7223065, 374175 7223065...
# 2  MULTIPOLYGON (((359085 7226005, 359085 7226035...
# 3  MULTIPOLYGON (((380745 7232815, 380895 7232815...
# 4  MULTIPOLYGON (((367395 7230445, 367365 7230445...

# %%
import geopandas as gpd
import pandas as pd

# -----------------------------
# 1. Set paths
# -----------------------------
my_path = "/vsis3/dcceew-eds-data/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p089r080/outputs/YOUR_OUTPUT_SHAPEFILE.shp"

roshan_path = "/vsis3/dcceew-rs-data/dcceew_202602_run/lzolre_p090r077_d2025081720260201_dlwm6_completed/lzolre_p090r077_d2025081720260201_dlwm6_completed_checked.shp"

# -----------------------------
# 2. Read files
# -----------------------------
my_gdf = gpd.read_file(my_path)
roshan_gdf = gpd.read_file(roshan_path)

print("My columns:", list(my_gdf.columns))
print("Roshan columns:", list(roshan_gdf.columns))
print("My CRS:", my_gdf.crs)
print("Roshan CRS:", roshan_gdf.crs)
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[2], line 14
#       9 roshan_path = "/vsis3/dcceew-rs-data/dcceew_202602_run/lzolre_p090r077_d2025081720260201_dlwm6_completed/lzolre_p090r077_d2025081720260201_dlwm6_completed_checked.shp"
#      11 # -----------------------------
#      12 # 2. Read files
#      13 # -----------------------------
# ---> 14 my_gdf = gpd.read_file(my_path)
#      15 roshan_gdf = gpd.read_file(roshan_path)
#      17 print("My columns:", list(my_gdf.columns))
#
# File /env/lib/python3.12/site-packages/geopandas/io/file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
# ...
