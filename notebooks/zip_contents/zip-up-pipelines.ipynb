# %% [markdown]
# # Zip up pipelines

# %%
# !cd /home/jovyan/work-easi-eds/scripts/easi-scripts && \
tar -czvf optimised_ndvi.tar.gz optimised_ndvi
# Out:
# optimised_ndvi/
# optimised_ndvi/scripts/
# optimised_ndvi/scripts/ndvi_master_pipeline.py
# optimised_ndvi/scripts/tasks/
# optimised_ndvi/scripts/tasks/task03_process_scene_ndvi.py
# optimised_ndvi/scripts/tasks/task02_build_scene_manifest.py
# optimised_ndvi/scripts/tasks/__pycache__/
# optimised_ndvi/scripts/tasks/__pycache__/task01_inventory_s3.cpython-312.pyc
# optimised_ndvi/scripts/tasks/__pycache__/task03_process_scene_ndvi.cpython-312.pyc
# optimised_ndvi/scripts/tasks/__pycache__/task02_build_scene_manifest.cpython-312.pyc
# optimised_ndvi/scripts/tasks/task01_inventory_s3.py
# optimised_ndvi/scripts/lib/
# optimised_ndvi/scripts/lib/cog.py
# optimised_ndvi/scripts/lib/s3_io.py
# optimised_ndvi/scripts/lib/geo.py
# optimised_ndvi/scripts/lib/tile_grid.py
# optimised_ndvi/scripts/lib/records.py
# optimised_ndvi/scripts/lib/__pycache__/
# optimised_ndvi/scripts/lib/__pycache__/records.cpython-312.pyc
# optimised_ndvi/scripts/lib/__pycache__/cog.cpython-312.pyc
# ...

# %%
# !ls -lh /home/jovyan/optimised_ndvi.tar.gz
# Out:
# ls: cannot access '/home/jovyan/optimised_ndvi.tar.gz': No such file or directory

# %%
# !cd /home/jovyan/work-easi-eds/scripts/easi-scripts && \
tar -czvf optimised_processing.tar.gz optimised_processing
# Out:
# optimised_processing/
# optimised_processing/scripts/
# optimised_processing/scripts/eds_master_pipeline_optimised.py
# optimised_processing/scripts/methods/
# optimised_processing/scripts/methods/legacy_window_ndvi_envi.py
# optimised_processing/scripts/tasks/
# optimised_processing/scripts/tasks/task03_process_scene_ndvi.py
# optimised_processing/scripts/tasks/task04_build_ga0_sr_composite.py
# optimised_processing/scripts/tasks/task02_build_scene_manifest.py
# optimised_processing/scripts/tasks/__pycache__/
# optimised_processing/scripts/tasks/__pycache__/task05_run_legacy_method.cpython-312.pyc
# optimised_processing/scripts/tasks/__pycache__/task08_masks_and_vectors.cpython-312.pyc
# optimised_processing/scripts/tasks/__pycache__/task02_resolve_sr_dates.cpython-312.pyc
# optimised_processing/scripts/tasks/__pycache__/task07_stage_ga1_locally.cpython-312.pyc
# optimised_processing/scripts/tasks/__pycache__/task09_copy_run_to_home.cpython-312.pyc
# ...
