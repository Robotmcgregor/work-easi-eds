# %%
# !aws sts get-caller-identity
# Out:
# {
#     "UserId": "AROAZ6PFZYT4B4C7MNRHV:robotmcgregor",
#     "Account": "683918607608",
#     "Arn": "arn:aws:sts::683918607608:assumed-role/dcceew-prod-csiro-easihub-client/robotmcgregor"
# }

# %%
from pathlib import Path

S3_SCRATCH = "s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor"
LOCAL_SCRATCH = Path.home() / "scratch"

print("S3 scratch:", S3_SCRATCH)
print("Local scratch:", LOCAL_SCRATCH)
# Out:
# S3 scratch: s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor
# Local scratch: /home/jovyan/scratch

# %%
# !aws s3 ls "s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/"
# Out:
#                            PRE eds/

# %%
# !ls -lh /home/jovyan/scratch/eds
# Out:
# total 8.0K
# drwxr-xr-x. 31 jovyan users 6.0K Feb  9 00:37 queries
# drwxr-xr-x. 42 jovyan users 6.0K Feb  9 07:33 tiles

# %%
# !du -sh /home/jovyan/scratch/eds/tiles
# Out:
# 20T	/home/jovyan/scratch/eds/tiles

# %%
S3_BASE = "s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor"
S3_TILES = f"{S3_BASE}/eds/tiles"

print(S3_TILES)
# Out:
# s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles

# %%
# !aws s3 mkdir s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/
# Out:
# usage: aws [options] <command> <subcommand> [<subcommand> ...] [parameters]
# To see help text, you can run:
#
#   aws help
#   aws <command> help
#   aws <command> <subcommand> help
#
# aws: error: argument subcommand: Invalid choice, valid choices are:
#
# ls                                       | website
# cp                                       | mv
# rm                                       | sync
# mb                                       | rb
# presign

# %%
# !aws s3 sync \
  /home/jovyan/scratch/eds/tiles/ \
  s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/
# Out:
# upload: ../../../scratch/eds/tiles/p091r076/sr/2016/201602/ls89sr_p091r076_20160213_nbart6m6_clr.tif.metadata.json to s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p091r076/sr/2016/201602/ls89sr_p091r076_20160213_nbart6m6_clr.tif.metadata.json
# upload: ../../../scratch/eds/tiles/p091r076/sr/2016/201607/ls89sr_p091r076_20160706_nbart6m6_clr.tif.metadata.json to s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p091r076/sr/2016/201607/ls89sr_p091r076_20160706_nbart6m6_clr.tif.metadata.json
# upload: ../../../scratch/eds/tiles/p091r076/sr/2016/201605/ls89sr_p091r076_20160519_nbart6m6_clr.tif.metadata.json to s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/p091r076/sr/2016/201605/ls89sr_p091r076_20160519_nbart6m6_clr.tif.metadata.json
# ...

# %%
# !aws s3 ls \
  s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/ \
  --recursive | head

# %%
# !aws s3 ls \
  s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/ \
  --recursive --summarize

# %%
# !aws s3 ls \
  s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/eds/tiles/ | head

# %% [markdown]
# # Step 3 — Delete local data (safe command)

# %%
# !rm -rf /home/jovyan/scratch/eds/compat/

# %%
S3_EDS_PROJECT = "s3://dcceew-eds/AROAZ6PFZYT4B4C7MNRHV:robotmcgreor"

# %%
# !aws s3 ls s3://dcceew-rs-data/AROAZ6PFZYT4B4C7MNRHV:robotmcgreor

# %%
# !aws s3 ls s3://dcceew-rs-data/AROAZ6PFZYT4B4C7MNRHV:robotmcgreor

# %%
# !echo "EDS S3 write test $(date)" > /home/jovyan/scratch/s3_test.txt
# !ls -lh /home/jovyan/scratch/s3_test.txt
# Out:
# -rw-r--r--. 1 jovyan users 47 Feb 10 03:09 /home/jovyan/scratch/s3_test.txt

# %%
# !aws s3 cp \
  /home/jovyan/scratch/s3_test.txt \
  s3://dcceew-rs-data/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/s3_test.txt
# Out:
# upload: ../../../scratch/s3_test.txt to s3://dcceew-rs-data/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/s3_test.txt

# %%
# !aws s3 ls s3://dcceew-rs-data/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/
# Out:
# 2026-02-10 03:09:49         47 s3_test.txt
