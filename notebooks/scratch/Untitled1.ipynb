# %%
cd s3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/
# Out:
# [Errno 2] No such file or directory: 's3://dcceew-prod-user-scratch/AROAZ6PFZYT4B4C7MNRHV:robotmcgregor/'
# /home/jovyan/work-easi-eds/notebooks/scratch
