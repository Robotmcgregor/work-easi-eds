# %%
# !tar -czvf /home/jovyan/scratch/optimised_ndvi.tar.gz \
    -C /home/jovyan/work-easi-eds/scripts/easi-scripts \
    optimised_ndvi
# Out:
# optimised_ndvi/
# optimised_ndvi/scripts/
# optimised_ndvi/scripts/ndvi_master_pipeline.py
# optimised_ndvi/scripts/tasks/
# optimised_ndvi/scripts/tasks/task03_process_scene_ndvi.py
# optimised_ndvi/scripts/tasks/task02_build_scene_manifest.py
# optimised_ndvi/scripts/tasks/__pycache__/
# optimised_ndvi/scripts/tasks/__pycache__/task01_inventory_s3.cpython-312.pyc
# optimised_ndvi/scripts/tasks/__pycache__/task03_process_scene_ndvi.cpython-312.pyc
# optimised_ndvi/scripts/tasks/__pycache__/task02_build_scene_manifest.cpython-312.pyc
# optimised_ndvi/scripts/tasks/task01_inventory_s3.py
# optimised_ndvi/scripts/lib/
# optimised_ndvi/scripts/lib/cog.py
# optimised_ndvi/scripts/lib/s3_io.py
# optimised_ndvi/scripts/lib/geo.py
# optimised_ndvi/scripts/lib/tile_grid.py
# optimised_ndvi/scripts/lib/records.py
# optimised_ndvi/scripts/lib/__pycache__/
# optimised_ndvi/scripts/lib/__pycache__/records.cpython-312.pyc
# optimised_ndvi/scripts/lib/__pycache__/cog.cpython-312.pyc
# ...

# %%
# !ls -lh /home/jovyan/scratch/optimised_ndvi.tar.gz
# Out:
# -rw-r--r--. 1 jovyan users 33K Feb 18 05:15 /home/jovyan/scratch/optimised_ndvi.tar.gz

# %%
# !tar -czvf /home/jovyan/scratch/eds-processing.tar.gz \
    -C /home/jovyan/work-easi-eds/scripts/easi-scripts \
    eds-processing
# Out:
# eds-processing/
# eds-processing/easi_slats_compat_builder_fc.py
# eds-processing/easi_eds_master_processing_pipeline.py
# eds-processing/easi_slats_compat_builder_sr_ndvi_orig_duplicate_4and8.py
# eds-processing/easi_eds_legacy_method_window_sr_ndvi_calibrate40_80.py
# eds-processing/easi_slats_compat_builder_sr_ndvi.py
# eds-processing/easi_slats_compat_builder_sr.py
# eds-processing/easi_eds_legacy_method_window_fc_before_log_nana_edit.py
# eds-processing/easi_polygonize_merged_thresholds_calibrate40_80.txt
# eds-processing/easi_polygonize_merged_thresholds_calibrate40_80_v2.py
# eds-processing/easi_package_eds_outputs.py
# eds-processing/.ipynb_checkpoints/
# eds-processing/.ipynb_checkpoints/easi_eds_legacy_method_window-checkpoint.py
# eds-processing/.ipynb_checkpoints/easi_eds_master_processing_pipeline-checkpoint.py
# eds-processing/.ipynb_checkpoints/easi_slats_compat_builder-checkpoint.py
# eds-processing/.ipynb_checkpoints/easi_package_eds_outputs-checkpoint.py
# ...

# %%
# !ls -lh /home/jovyan/scratch/eds-processing.tar.gz
# Out:
# -rw-r--r--. 1 jovyan users 148K Feb 18 05:12 /home/jovyan/scratch/eds-processingn.tar.gz

# %%
# !tar -czvf /home/jovyan/scratch/optimised-eds-processing2.tar.gz \
    -C /home/jovyan/work-easi-eds/scripts/easi-scripts/ \
    optimised_processing
# Out:
# optimised_processing/
# optimised_processing/scripts/
# optimised_processing/scripts/eds_master_pipeline_optimised.py
# optimised_processing/scripts/methods/
# optimised_processing/scripts/methods/legacy_window_ndvi_envi.py
# optimised_processing/scripts/tasks/
# optimised_processing/scripts/tasks/task04_build_db8_sr_composite.py
# optimised_processing/scripts/tasks/task03_process_scene_ndvi.py
# optimised_processing/scripts/tasks/task02_build_scene_manifest.py
# optimised_processing/scripts/tasks/__pycache__/
# optimised_processing/scripts/tasks/__pycache__/task05_run_legacy_method.cpython-312.pyc
# optimised_processing/scripts/tasks/__pycache__/task08_masks_and_vectors.cpython-312.pyc
# optimised_processing/scripts/tasks/__pycache__/task02_resolve_sr_dates.cpython-312.pyc
# optimised_processing/scripts/tasks/__pycache__/task09_copy_run_to_home.cpython-312.pyc
# optimised_processing/scripts/tasks/__pycache__/task03_ensure_seasonal_ndvi.cpython-312.pyc
# ...

# %%
# !ls -lh /home/jovyan/scratch/optimised-eds-processing.tar.gz
# Out:
# -rw-r--r--. 1 jovyan users 68K Feb 19 22:40 /home/jovyan/scratch/optimised-eds-processing.tar.gz

# %%
# !tar -czvf /home/jovyan/scratch/eds-processing2.tar.gz \
    -C /home/jovyan/work-easi-eds/scripts/easi-scripts/ \
    eds-processing
# Out:
# eds-processing/
# eds-processing/easi_slats_compat_builder_fc.py
# eds-processing/easi_eds_master_processing_pipeline.py
# eds-processing/easi_slats_compat_builder_sr_ndvi_orig_duplicate_4and8.py
# eds-processing/easi_eds_legacy_method_window_sr_ndvi_calibrate40_80.py
# eds-processing/easi_slats_compat_builder_sr_ndvi.py
# eds-processing/easi_slats_compat_builder_sr.py
# eds-processing/easi_eds_legacy_method_window_fc_before_log_nana_edit.py
# eds-processing/easi_polygonize_merged_thresholds_calibrate40_80.txt
# eds-processing/easi_polygonize_merged_thresholds_calibrate40_80_v2.py
# eds-processing/easi_package_eds_outputs.py
# eds-processing/.ipynb_checkpoints/
# eds-processing/.ipynb_checkpoints/easi_eds_legacy_method_window-checkpoint.py
# eds-processing/.ipynb_checkpoints/easi_eds_master_processing_pipeline-checkpoint.py
# eds-processing/.ipynb_checkpoints/easi_slats_compat_builder-checkpoint.py
# eds-processing/.ipynb_checkpoints/easi_package_eds_outputs-checkpoint.py
# ...
